# %% [markdown]
# # 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd '../gdrive/MyDrive/SSAC/3조'
# Out:
# /gdrive/.shortcut-targets-by-id/15_BxZVEQYCdGCGiQ5nexpWPc1cgHVe4w/3조

# %% [markdown]
# # DeepFM

# %%
import deepctr_torch

# %%
# !pip install -U deepctr-torch

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

from deepctr_torch.inputs import SparseFeat, DenseFeat, get_feature_names
from deepctr_torch.models import *

# %% [markdown]
# # 파일 불러오기

# %% [markdown]
# - 이미지 벡터 없는 파일

# %%
df = pd.read_csv('data/total_data.csv')
df.head(2)
# Out:
#    content_id                imp_id view_time  ...  b_pay_rate    sec  title_len
# 0   137078818  99d1612dded122458e99  16:56:46  ...    0.394224  484.0         34
# 1   137078818  99d1612d825321055790  00:00:00  ...    0.394224    7.0         34
#
# [2 rows x 44 columns]

# %% [markdown]
# - 이미지 벡터 포함한 파일

# %%
df['content_place'].value_counts()
# Out:
# 전국        337762
# 경기도       151537
# 서울특별시     145182
# 대구광역시      36163
# 부산광역시      23272
# 인천광역시      16085
# 대전광역시      15283
# 충청북도        4177
# 전라북도        2632
# 경상북도        2389
# 경상남도        1212
# Name: content_place, dtype: int64

# %%
df = pd.read_csv('data/total_data_img.csv', low_memory=False)

# %% [markdown]
# # 준비

# %% [markdown]
# - 평가함수 정의

# %%
from sklearn.metrics import log_loss, roc_auc_score

grouped_label = df.groupby('label').size()
average_ctr = float(grouped_label[1]/grouped_label.sum())
average_ctr

def get_rig(train_y, test_y, pred):
    avg_ctr = average_ctr
    prior = log_loss(train_y, [avg_ctr]*len(train_y))

    classifier = log_loss(test_y, pred)

    rig = (prior - classifier) / prior
    return rig

# %% [markdown]
# # 전처리

# %% [markdown]
# ### 학습에 사용할 feature 분류

# %%
categorical = [
    'viewer_gender',
    'content_used',
    'content_cat_1',
    'content_cat_2',
    'content_cat_3',
    "content_status",
    'content_delivery_fee',
    'content_b_pay', 
    'content_place'
    ]
continuous = [
    'bid_price', 
    'content_price',
    # 'content_emergency_count',
    'content_comment_count',     
    'content_views',       
    'content_likes',
    'adv_follower_count',
    # 'adv_grade',       
    'adv_item_count',         
    'adv_views',
    'adv_review_count',
    'adv_comment_count',
    'adv_pay_count',
    'adv_parcel_post_count', 
    'adv_transfer_count', 
    # 'adv_chat_count',
    'viewer_age',
    'viewer_following_count',
    'viewer_pay_count',
    "viewer_parcel_post_count",
    'viewer_transfer_count',
    'viewer_chat_count', 
    # 'b_pay_rate',
    # 'viewer_age_ch',
    # 'sec', 
    'title_len'
    ]

# 이미지 벡터 사용하는 경우
vec_features = [str(i) for i in range(512)]

# %% [markdown]
# ### 결측치

# %%
# 결측치 채우기
df[categorical] = df[categorical].fillna('-1', )
df[continuous] = df[continuous].fillna(0, )
target = ['label']

# %% [markdown]
# ### Label Encoding, Scaling

# %%
# # categorical 데이터는 Label Encoding
for feat in categorical:
    lbe = LabelEncoder()
    df[feat] = lbe.fit_transform(df[feat])

# categorical 데이터는 One-hot Encoding
# df = pd.get_dummies(df, columns=categorical, drop_first=True)

# continuous 데이터는 Min-Max Scaling
# scaler = MinMaxScaler(feature_range=(0, 1))

# continuous 데이터는 Standard Scaling
scaler = StandardScaler()
df[continuous] = scaler.fit_transform(df[continuous])

# %%
categorical = df.columns[35:].tolist()

# %%
df.columns[34:]
# Out:
# Index(['title_len', 'viewer_gender_1', 'viewer_gender_2', 'content_used_1',
#        'content_cat_1_가방', 'content_cat_1_기타', 'content_cat_1_남성 악세사리',
#        'content_cat_1_남성 의류', 'content_cat_1_도서/티켓/문구', 'content_cat_1_미용품',
#        ...
#        'content_place_경상남도', 'content_place_경상북도', 'content_place_대구광역시',
#        'content_place_대전광역시', 'content_place_부산광역시 ', 'content_place_서울특별시',
#        'content_place_인천광역시', 'content_place_전국', 'content_place_전라북도',
#        'content_place_충청북도'],
#       dtype='object', length=316)

# %%
scaler = StandardScaler()
df[vec_features] = scaler.fit_transform(df[vec_features])

# %%
continuous = continuous + vec_features

# %%
len(df.columns)
# Out:
# 44

# %% [markdown]
# ### train test split

# %%
# 3.generate input data for model

train, test = train_test_split(df, test_size=0.2, random_state=47)#, stratify=df['label'])

# %% [markdown]
# ### 각 feature 정보를 형식에 맞춰 저장

# %%
# 2.count #unique features for each sparse field,and record dense feature field name

# 각 feature마다 값의 종류가 몇개인지, feature 이름이 무엇인지 등 저장
fixlen_feature_columns = [SparseFeat(feat, df[feat].nunique())
                            for feat in categorical] + [DenseFeat(feat, 1, )
                                                            for feat in continuous]

# dnn feature에 일단 모든 feature 정보 넣기
dnn_feature_columns = fixlen_feature_columns

# lenear feature에도 일단 모든 feature 정보 넣기
linear_feature_columns = fixlen_feature_columns 

# feature 이름들만 따로 저장
feature_names = get_feature_names(
    linear_feature_columns + dnn_feature_columns)

# %%
# train/test 데이터의 각 feature에 대응하는 컬럼을 딕셔너리로 저장
train_model_input = {name: train[name] for name in feature_names}
test_model_input = {name: test[name] for name in feature_names}

# %% [markdown]
# ## 파라미터 목록

# %% [markdown]
# - DeepFM(linear_feature_columns, dnn_feature_columns, use_fm=True, dnn_hidden_units=(256, 128), l2_reg_linear=1e-05, l2_reg_embedding=1e-05, l2_reg_dnn=0, init_std=0.0001, seed=1024, dnn_dropout=0, dnn_activation='relu', dnn_use_bn=False, task='binary', device='cpu', gpus=None)
# ### Parameters:
# - linear_feature_columns – An iterable containing all the features used by linear part of the model.
# - dnn_feature_columns – An iterable containing all the features used by deep part of the model.
# - use_fm – bool,use FM part or not
# - dnn_hidden_units – list,list of positive integer or empty list, the layer - - number and units in each layer of DNN
# - l2_reg_linear – float. L2 regularizer strength applied to linear part
# - l2_reg_embedding – float. L2 regularizer strength applied to embedding vector
# - l2_reg_dnn – float. L2 regularizer strength applied to DNN
# - init_std – float,to use as the initialize std of embedding vector
# - seed – integer ,to use as random seed.
# - dnn_dropout – float in [0,1), the probability we will drop out a given DNN coordinate.
# - dnn_activation – Activation function to use in DNN
# - dnn_use_bn – bool. Whether use BatchNormalization before activation or not in DNN
# - task – str, "binary" for binary logloss or "regression" for regression loss
# - device – str, "cpu" or "cuda:0"
# - gpus – list of int or torch.device for multiple gpus. If None, run on device. gpus[0] should be the same gpu with device.

# %%
# linear_feature_columns – An iterable containing all the features used by linear part of the model.
# dnn_feature_columns – An iterable containing all the features used by deep part of the model.
use_fm – True / False
# dnn_hidden_units – list,list of positive integer or empty list, the layer - - number and units in each layer of DNN
# l2_reg_linear – float. L2 regularizer strength applied to linear part
# l2_reg_embedding – float. L2 regularizer strength applied to embedding vector
# l2_reg_dnn – float. L2 regularizer strength applied to DNN
# init_std – float,to use as the initialize std of embedding vector
seed – integer ,to use as random seed.
dnn_dropout – 0~1
dnn_activation – 'relu', 'tanh'
dnn_use_bn – True / False
task – "binary"
device – "cpu" or "cuda:0"
gpus – list of int or torch.device for multiple gpus. If None, run on device. gpus[0] should be the same gpu with device.

# %% [markdown]
# # 학습

# %%
# !nvidia-smi
# Out:
# Mon Dec 27 02:22:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    32W / 250W |   1169MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 크롤링 불가능한 3개 feature 제외

# %% [markdown]
# ## One hot

# %% [markdown]
# - one-hot encoding, `adv_grade`, `adv_chat`, `content_emergency` 제외
# - category 1, 2, 3

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 229s - loss:  0.1378 - binary_crossentropy:  0.1378 - auc:  0.6844 - val_binary_crossentropy:  0.1335 - val_auc:  0.6935
# Epoch 2/20
# 227s - loss:  0.1353 - binary_crossentropy:  0.1353 - auc:  0.6987 - val_binary_crossentropy:  0.1315 - val_auc:  0.7050
# Epoch 3/20
# 228s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7115 - val_binary_crossentropy:  0.1312 - val_auc:  0.7056
# Epoch 4/20
# 225s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7178 - val_binary_crossentropy:  0.1318 - val_auc:  0.7072
# Epoch 5/20
# 224s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7218 - val_binary_crossentropy:  0.1303 - val_auc:  0.7136
# Epoch 6/20
# 227s - loss:  0.1326 - binary_crossentropy:  0.1327 - auc:  0.7259 - val_binary_crossentropy:  0.1314 - val_auc:  0.7148
# Epoch 7/20
# 228s - loss:  0.1318 - binary_crossentropy:  0.1318 - auc:  0.7302 - val_binary_crossentropy:  0.1313 - val_auc:  0.7198
# Epoch 8/20
# 229s - loss:  0.1317 - binary_crossentropy:  0.1317 - auc:  0.7331 - val_binary_crossentropy:  0.1301 - val_auc:  0.7203
# Epoch 9/20
# 228s - loss:  0.1309 - binary_crossentropy:  0.1309 - auc:  0.7373 - val_binary_crossentropy:  0.1302 - val_auc:  0.7189
# Epoch 10/20
# 231s - loss:  0.1308 - binary_crossentropy:  0.1308 - auc:  0.7402 - val_binary_crossentropy:  0.1301 - val_auc:  0.7217
# Epoch 11/20
# 231s - loss:  0.1303 - binary_crossentropy:  0.1303 - auc:  0.7429 - val_binary_crossentropy:  0.1299 - val_auc:  0.7220
# Epoch 12/20
# 227s - loss:  0.1303 - binary_crossentropy:  0.1301 - auc:  0.7475 - val_binary_crossentropy:  0.1296 - val_auc:  0.7221
# Epoch 13/20
# 228s - loss:  0.1295 - binary_crossentropy:  0.1295 - auc:  0.7499 - val_binary_crossentropy:  0.1296 - val_auc:  0.7248
# Epoch 14/20
# 228s - loss:  0.1290 - binary_crossentropy:  0.1290 - auc:  0.7547 - val_binary_crossentropy:  0.1309 - val_auc:  0.7262
# Epoch 15/20
# 226s - loss:  0.1287 - binary_crossentropy:  0.1287 - auc:  0.7547 - val_binary_crossentropy:  0.1304 - val_auc:  0.7208
# Epoch 16/20
# 225s - loss:  0.1285 - binary_crossentropy:  0.1285 - auc:  0.7585 - val_binary_crossentropy:  0.1294 - val_auc:  0.7271
# Epoch 17/20
# 226s - loss:  0.1278 - binary_crossentropy:  0.1277 - auc:  0.7616 - val_binary_crossentropy:  0.1306 - val_auc:  0.7241
# Epoch 18/20
# 227s - loss:  0.1280 - binary_crossentropy:  0.1277 - auc:  0.7634 - val_binary_crossentropy:  0.1307 - val_auc:  0.7250
# Epoch 19/20
# 228s - loss:  0.1273 - binary_crossentropy:  0.1273 - auc:  0.7655 - val_binary_crossentropy:  0.1328 - val_auc:  0.7224
# Epoch 20/20
# 228s - loss:  0.1268 - binary_crossentropy:  0.1268 - auc:  0.7682 - val_binary_crossentropy:  0.1315 - val_auc:  0.7218
#
# test LogLoss 0.1338
# test AUC 0.722
# test RIG 0.0545

# %% [markdown]
# - one-hot encoding, `adv_grade`, `adv_chat`, `content_emergency` 제외
# - category 2

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 61s - loss:  0.1381 - binary_crossentropy:  0.1381 - auc:  0.6856 - val_binary_crossentropy:  0.1319 - val_auc:  0.6974
# Epoch 2/20
# 60s - loss:  0.1345 - binary_crossentropy:  0.1345 - auc:  0.7033 - val_binary_crossentropy:  0.1305 - val_auc:  0.7101
# Epoch 3/20
# 59s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7183 - val_binary_crossentropy:  0.1303 - val_auc:  0.7137
# Epoch 4/20
# 60s - loss:  0.1322 - binary_crossentropy:  0.1323 - auc:  0.7259 - val_binary_crossentropy:  0.1297 - val_auc:  0.7197
# Epoch 5/20
# 59s - loss:  0.1314 - binary_crossentropy:  0.1314 - auc:  0.7317 - val_binary_crossentropy:  0.1294 - val_auc:  0.7218
# Epoch 6/20
# 59s - loss:  0.1308 - binary_crossentropy:  0.1308 - auc:  0.7350 - val_binary_crossentropy:  0.1294 - val_auc:  0.7197
# Epoch 7/20
# 60s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7402 - val_binary_crossentropy:  0.1286 - val_auc:  0.7295
# Epoch 8/20
# 59s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7452 - val_binary_crossentropy:  0.1305 - val_auc:  0.7269
# Epoch 9/20
# 59s - loss:  0.1291 - binary_crossentropy:  0.1291 - auc:  0.7481 - val_binary_crossentropy:  0.1286 - val_auc:  0.7329
# Epoch 10/20
# 59s - loss:  0.1286 - binary_crossentropy:  0.1286 - auc:  0.7540 - val_binary_crossentropy:  0.1288 - val_auc:  0.7302
# Epoch 11/20
# 59s - loss:  0.1278 - binary_crossentropy:  0.1279 - auc:  0.7570 - val_binary_crossentropy:  0.1290 - val_auc:  0.7302
# Epoch 12/20
# 59s - loss:  0.1274 - binary_crossentropy:  0.1275 - auc:  0.7611 - val_binary_crossentropy:  0.1291 - val_auc:  0.7306
# Epoch 13/20
# 59s - loss:  0.1268 - binary_crossentropy:  0.1268 - auc:  0.7655 - val_binary_crossentropy:  0.1286 - val_auc:  0.7348
# Epoch 14/20
# 60s - loss:  0.1264 - binary_crossentropy:  0.1264 - auc:  0.7675 - val_binary_crossentropy:  0.1291 - val_auc:  0.7330
# Epoch 15/20
# 59s - loss:  0.1259 - binary_crossentropy:  0.1259 - auc:  0.7709 - val_binary_crossentropy:  0.1287 - val_auc:  0.7347
# Epoch 16/20
# 59s - loss:  0.1252 - binary_crossentropy:  0.1252 - auc:  0.7756 - val_binary_crossentropy:  0.1288 - val_auc:  0.7380
# Epoch 17/20
# 60s - loss:  0.1248 - binary_crossentropy:  0.1248 - auc:  0.7782 - val_binary_crossentropy:  0.1292 - val_auc:  0.7346
# Epoch 18/20
# 59s - loss:  0.1243 - binary_crossentropy:  0.1243 - auc:  0.7822 - val_binary_crossentropy:  0.1296 - val_auc:  0.7364
# Epoch 19/20
# 59s - loss:  0.1237 - binary_crossentropy:  0.1237 - auc:  0.7843 - val_binary_crossentropy:  0.1293 - val_auc:  0.7379
# Epoch 20/20
# 60s - loss:  0.1233 - binary_crossentropy:  0.1234 - auc:  0.7870 - val_binary_crossentropy:  0.1289 - val_auc:  0.7392
#
# test LogLoss 0.1325
# test AUC 0.7372
# test RIG 0.0639

# %% [markdown]
# - one-hot encoding, `adv_grade`, `adv_chat`, `content_emergency` 제외
# - category 1

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 27s - loss:  0.1390 - binary_crossentropy:  0.1390 - auc:  0.6781 - val_binary_crossentropy:  0.1322 - val_auc:  0.6926
# Epoch 2/20
# 26s - loss:  0.1350 - binary_crossentropy:  0.1350 - auc:  0.6968 - val_binary_crossentropy:  0.1317 - val_auc:  0.7002
# Epoch 3/20
# 26s - loss:  0.1337 - binary_crossentropy:  0.1337 - auc:  0.7101 - val_binary_crossentropy:  0.1306 - val_auc:  0.7123
# Epoch 4/20
# 26s - loss:  0.1328 - binary_crossentropy:  0.1327 - auc:  0.7178 - val_binary_crossentropy:  0.1301 - val_auc:  0.7154
# Epoch 5/20
# 26s - loss:  0.1322 - binary_crossentropy:  0.1322 - auc:  0.7234 - val_binary_crossentropy:  0.1298 - val_auc:  0.7174
# Epoch 6/20
# 26s - loss:  0.1316 - binary_crossentropy:  0.1316 - auc:  0.7283 - val_binary_crossentropy:  0.1292 - val_auc:  0.7236
# Epoch 7/20
# 26s - loss:  0.1310 - binary_crossentropy:  0.1310 - auc:  0.7325 - val_binary_crossentropy:  0.1295 - val_auc:  0.7226
# Epoch 8/20
# 28s - loss:  0.1305 - binary_crossentropy:  0.1305 - auc:  0.7372 - val_binary_crossentropy:  0.1290 - val_auc:  0.7251
# Epoch 9/20
# 26s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7410 - val_binary_crossentropy:  0.1293 - val_auc:  0.7270
# Epoch 10/20
# 26s - loss:  0.1294 - binary_crossentropy:  0.1294 - auc:  0.7454 - val_binary_crossentropy:  0.1290 - val_auc:  0.7305
# Epoch 11/20
# 26s - loss:  0.1288 - binary_crossentropy:  0.1288 - auc:  0.7497 - val_binary_crossentropy:  0.1284 - val_auc:  0.7309
# Epoch 12/20
# 26s - loss:  0.1282 - binary_crossentropy:  0.1281 - auc:  0.7536 - val_binary_crossentropy:  0.1283 - val_auc:  0.7329
# Epoch 13/20
# 26s - loss:  0.1277 - binary_crossentropy:  0.1277 - auc:  0.7571 - val_binary_crossentropy:  0.1286 - val_auc:  0.7302
# Epoch 14/20
# 26s - loss:  0.1270 - binary_crossentropy:  0.1270 - auc:  0.7617 - val_binary_crossentropy:  0.1290 - val_auc:  0.7295
# Epoch 15/20
# 26s - loss:  0.1266 - binary_crossentropy:  0.1266 - auc:  0.7652 - val_binary_crossentropy:  0.1287 - val_auc:  0.7312
# Epoch 16/20
# 26s - loss:  0.1278 - binary_crossentropy:  0.1266 - auc:  0.7694 - val_binary_crossentropy:  0.1286 - val_auc:  0.7356
# Epoch 17/20
# 26s - loss:  0.1255 - binary_crossentropy:  0.1255 - auc:  0.7728 - val_binary_crossentropy:  0.1288 - val_auc:  0.7347
# Epoch 18/20
# 26s - loss:  0.1252 - binary_crossentropy:  0.1252 - auc:  0.7756 - val_binary_crossentropy:  0.1296 - val_auc:  0.7302
# Epoch 19/20
# 26s - loss:  0.1244 - binary_crossentropy:  0.1244 - auc:  0.7780 - val_binary_crossentropy:  0.1299 - val_auc:  0.7299
# Epoch 20/20
# 26s - loss:  0.1239 - binary_crossentropy:  0.1239 - auc:  0.7813 - val_binary_crossentropy:  0.1291 - val_auc:  0.7359
#
# test LogLoss 0.1313
# test AUC 0.7359
# test RIG 0.0727

# %% [markdown]
# ## Label

# %% [markdown]
# - Label encoding, `adv_grade`, `adv_chat`, `content_emergency` 제외
# - Category 1

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 12s - loss:  0.1393 - binary_crossentropy:  0.1393 - auc:  0.6771 - val_binary_crossentropy:  0.1324 - val_auc:  0.6884
# Epoch 2/20
# 11s - loss:  0.1350 - binary_crossentropy:  0.1350 - auc:  0.6976 - val_binary_crossentropy:  0.1327 - val_auc:  0.6952
# Epoch 3/20
# 11s - loss:  0.1340 - binary_crossentropy:  0.1340 - auc:  0.7067 - val_binary_crossentropy:  0.1320 - val_auc:  0.6986
# Epoch 4/20
# 11s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7128 - val_binary_crossentropy:  0.1312 - val_auc:  0.7064
# Epoch 5/20
# 11s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7182 - val_binary_crossentropy:  0.1309 - val_auc:  0.7093
# Epoch 6/20
# 12s - loss:  0.1323 - binary_crossentropy:  0.1323 - auc:  0.7222 - val_binary_crossentropy:  0.1302 - val_auc:  0.7164
# Epoch 7/20
# 11s - loss:  0.1317 - binary_crossentropy:  0.1317 - auc:  0.7272 - val_binary_crossentropy:  0.1302 - val_auc:  0.7166
# Epoch 8/20
# 11s - loss:  0.1311 - binary_crossentropy:  0.1311 - auc:  0.7312 - val_binary_crossentropy:  0.1305 - val_auc:  0.7220
# Epoch 9/20
# 12s - loss:  0.1304 - binary_crossentropy:  0.1305 - auc:  0.7378 - val_binary_crossentropy:  0.1301 - val_auc:  0.7217
# Epoch 10/20
# 11s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7410 - val_binary_crossentropy:  0.1293 - val_auc:  0.7225
# Epoch 11/20
# 11s - loss:  0.1295 - binary_crossentropy:  0.1295 - auc:  0.7446 - val_binary_crossentropy:  0.1293 - val_auc:  0.7236
# Epoch 12/20
# 11s - loss:  0.1289 - binary_crossentropy:  0.1289 - auc:  0.7494 - val_binary_crossentropy:  0.1301 - val_auc:  0.7224
# Epoch 13/20
# 11s - loss:  0.1285 - binary_crossentropy:  0.1285 - auc:  0.7534 - val_binary_crossentropy:  0.1285 - val_auc:  0.7290
# Epoch 14/20
# 11s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7562 - val_binary_crossentropy:  0.1288 - val_auc:  0.7300
# Epoch 15/20
# 11s - loss:  0.1274 - binary_crossentropy:  0.1274 - auc:  0.7605 - val_binary_crossentropy:  0.1280 - val_auc:  0.7344
# Epoch 16/20
# 11s - loss:  0.1273 - binary_crossentropy:  0.1272 - auc:  0.7638 - val_binary_crossentropy:  0.1289 - val_auc:  0.7316
# Epoch 17/20
# 11s - loss:  0.1266 - binary_crossentropy:  0.1266 - auc:  0.7657 - val_binary_crossentropy:  0.1284 - val_auc:  0.7328
# Epoch 18/20
# 11s - loss:  0.1262 - binary_crossentropy:  0.1261 - auc:  0.7699 - val_binary_crossentropy:  0.1290 - val_auc:  0.7293
# Epoch 19/20
# 11s - loss:  0.1255 - binary_crossentropy:  0.1255 - auc:  0.7745 - val_binary_crossentropy:  0.1286 - val_auc:  0.7334
# Epoch 20/20
# 12s - loss:  0.1252 - binary_crossentropy:  0.1252 - auc:  0.7759 - val_binary_crossentropy:  0.1287 - val_auc:  0.7343
#
# test LogLoss 0.1309
# test AUC 0.7353
# test RIG 0.0755

# %% [markdown]
# - Label encoding, `adv_grade`, `adv_chat`, `content_emergency` 제외
# - Category 2

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 12s - loss:  0.1400 - binary_crossentropy:  0.1401 - auc:  0.6746 - val_binary_crossentropy:  0.1323 - val_auc:  0.6942
# Epoch 2/20
# 11s - loss:  0.1345 - binary_crossentropy:  0.1345 - auc:  0.7026 - val_binary_crossentropy:  0.1311 - val_auc:  0.7099
# Epoch 3/20
# 11s - loss:  0.1336 - binary_crossentropy:  0.1336 - auc:  0.7128 - val_binary_crossentropy:  0.1325 - val_auc:  0.7056
# Epoch 4/20
# 11s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7167 - val_binary_crossentropy:  0.1321 - val_auc:  0.6985
# Epoch 5/20
# 11s - loss:  0.1324 - binary_crossentropy:  0.1323 - auc:  0.7236 - val_binary_crossentropy:  0.1296 - val_auc:  0.7220
# Epoch 6/20
# 11s - loss:  0.1317 - binary_crossentropy:  0.1317 - auc:  0.7286 - val_binary_crossentropy:  0.1304 - val_auc:  0.7142
# Epoch 7/20
# 11s - loss:  0.1311 - binary_crossentropy:  0.1311 - auc:  0.7320 - val_binary_crossentropy:  0.1291 - val_auc:  0.7238
# Epoch 8/20
# 11s - loss:  0.1306 - binary_crossentropy:  0.1306 - auc:  0.7356 - val_binary_crossentropy:  0.1296 - val_auc:  0.7194
# Epoch 9/20
# 11s - loss:  0.1301 - binary_crossentropy:  0.1301 - auc:  0.7403 - val_binary_crossentropy:  0.1290 - val_auc:  0.7258
# Epoch 10/20
# 11s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7445 - val_binary_crossentropy:  0.1288 - val_auc:  0.7278
# Epoch 11/20
# 11s - loss:  0.1290 - binary_crossentropy:  0.1290 - auc:  0.7490 - val_binary_crossentropy:  0.1291 - val_auc:  0.7284
# Epoch 12/20
# 11s - loss:  0.1284 - binary_crossentropy:  0.1284 - auc:  0.7549 - val_binary_crossentropy:  0.1283 - val_auc:  0.7342
# Epoch 13/20
# 11s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7565 - val_binary_crossentropy:  0.1284 - val_auc:  0.7339
# Epoch 14/20
# 11s - loss:  0.1276 - binary_crossentropy:  0.1276 - auc:  0.7600 - val_binary_crossentropy:  0.1284 - val_auc:  0.7342
# Epoch 15/20
# 11s - loss:  0.1271 - binary_crossentropy:  0.1271 - auc:  0.7628 - val_binary_crossentropy:  0.1281 - val_auc:  0.7350
# Epoch 16/20
# 11s - loss:  0.1264 - binary_crossentropy:  0.1264 - auc:  0.7672 - val_binary_crossentropy:  0.1281 - val_auc:  0.7371
# Epoch 17/20
# 11s - loss:  0.1260 - binary_crossentropy:  0.1260 - auc:  0.7696 - val_binary_crossentropy:  0.1295 - val_auc:  0.7349
# Epoch 18/20
# 11s - loss:  0.1256 - binary_crossentropy:  0.1256 - auc:  0.7725 - val_binary_crossentropy:  0.1292 - val_auc:  0.7315
# Epoch 19/20
# 11s - loss:  0.1253 - binary_crossentropy:  0.1253 - auc:  0.7761 - val_binary_crossentropy:  0.1281 - val_auc:  0.7364
# Epoch 20/20
# 11s - loss:  0.1246 - binary_crossentropy:  0.1246 - auc:  0.7807 - val_binary_crossentropy:  0.1286 - val_auc:  0.7358
#
# test LogLoss 0.1311
# test AUC 0.7354
# test RIG 0.0737

# %% [markdown]
# - Label encoding, `adv_grade`, `adv_chat`, `content_emergency` 제외
# - Category 3

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 11s - loss:  0.1413 - binary_crossentropy:  0.1413 - auc:  0.6797 - val_binary_crossentropy:  0.1335 - val_auc:  0.6897
# Epoch 2/20
# 11s - loss:  0.1344 - binary_crossentropy:  0.1344 - auc:  0.7042 - val_binary_crossentropy:  0.1322 - val_auc:  0.6992
# Epoch 3/20
# 11s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7137 - val_binary_crossentropy:  0.1312 - val_auc:  0.7120
# Epoch 4/20
# 11s - loss:  0.1326 - binary_crossentropy:  0.1326 - auc:  0.7224 - val_binary_crossentropy:  0.1314 - val_auc:  0.7177
# Epoch 5/20
# 11s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7279 - val_binary_crossentropy:  0.1297 - val_auc:  0.7204
# Epoch 6/20
# 11s - loss:  0.1313 - binary_crossentropy:  0.1313 - auc:  0.7310 - val_binary_crossentropy:  0.1299 - val_auc:  0.7208
# Epoch 7/20
# 11s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7365 - val_binary_crossentropy:  0.1292 - val_auc:  0.7286
# Epoch 8/20
# 12s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7407 - val_binary_crossentropy:  0.1293 - val_auc:  0.7252
# Epoch 9/20
# 11s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7460 - val_binary_crossentropy:  0.1291 - val_auc:  0.7294
# Epoch 10/20
# 11s - loss:  0.1291 - binary_crossentropy:  0.1291 - auc:  0.7482 - val_binary_crossentropy:  0.1283 - val_auc:  0.7343
# Epoch 11/20
# 11s - loss:  0.1286 - binary_crossentropy:  0.1286 - auc:  0.7528 - val_binary_crossentropy:  0.1283 - val_auc:  0.7323
# Epoch 12/20
# 11s - loss:  0.1282 - binary_crossentropy:  0.1282 - auc:  0.7557 - val_binary_crossentropy:  0.1281 - val_auc:  0.7379
# Epoch 13/20
# 11s - loss:  0.1276 - binary_crossentropy:  0.1276 - auc:  0.7594 - val_binary_crossentropy:  0.1277 - val_auc:  0.7403
# Epoch 14/20
# 11s - loss:  0.1271 - binary_crossentropy:  0.1271 - auc:  0.7622 - val_binary_crossentropy:  0.1281 - val_auc:  0.7378
# Epoch 15/20
# 11s - loss:  0.1267 - binary_crossentropy:  0.1267 - auc:  0.7658 - val_binary_crossentropy:  0.1283 - val_auc:  0.7410
# Epoch 16/20
# 11s - loss:  0.1262 - binary_crossentropy:  0.1262 - auc:  0.7685 - val_binary_crossentropy:  0.1282 - val_auc:  0.7397
# Epoch 17/20
# 11s - loss:  0.1258 - binary_crossentropy:  0.1258 - auc:  0.7709 - val_binary_crossentropy:  0.1282 - val_auc:  0.7397
# Epoch 18/20
# 11s - loss:  0.1253 - binary_crossentropy:  0.1253 - auc:  0.7748 - val_binary_crossentropy:  0.1286 - val_auc:  0.7380
# Epoch 19/20
# 11s - loss:  0.1249 - binary_crossentropy:  0.1249 - auc:  0.7769 - val_binary_crossentropy:  0.1289 - val_auc:  0.7389
# Epoch 20/20
# 11s - loss:  0.1244 - binary_crossentropy:  0.1244 - auc:  0.7804 - val_binary_crossentropy:  0.1284 - val_auc:  0.7402
#
# test LogLoss 0.1312
# test AUC 0.7396
# test RIG 0.073

# %% [markdown]
# - Label encoding, `adv_grade`, `adv_chat`, `content_emergency` 제외
# - Category 1,2,3

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 13s - loss:  0.1411 - binary_crossentropy:  0.1411 - auc:  0.6809 - val_binary_crossentropy:  0.1316 - val_auc:  0.7040
# Epoch 2/20
# 12s - loss:  0.1342 - binary_crossentropy:  0.1341 - auc:  0.7086 - val_binary_crossentropy:  0.1313 - val_auc:  0.7040
# Epoch 3/20
# 12s - loss:  0.1330 - binary_crossentropy:  0.1330 - auc:  0.7185 - val_binary_crossentropy:  0.1311 - val_auc:  0.7118
# Epoch 4/20
# 12s - loss:  0.1322 - binary_crossentropy:  0.1322 - auc:  0.7245 - val_binary_crossentropy:  0.1305 - val_auc:  0.7153
# Epoch 5/20
# 12s - loss:  0.1316 - binary_crossentropy:  0.1317 - auc:  0.7296 - val_binary_crossentropy:  0.1315 - val_auc:  0.7021
# Epoch 6/20
# 12s - loss:  0.1309 - binary_crossentropy:  0.1309 - auc:  0.7350 - val_binary_crossentropy:  0.1310 - val_auc:  0.7198
# Epoch 7/20
# 12s - loss:  0.1304 - binary_crossentropy:  0.1304 - auc:  0.7387 - val_binary_crossentropy:  0.1294 - val_auc:  0.7239
# Epoch 8/20
# 14s - loss:  0.1298 - binary_crossentropy:  0.1298 - auc:  0.7426 - val_binary_crossentropy:  0.1292 - val_auc:  0.7262
# Epoch 9/20
# 13s - loss:  0.1293 - binary_crossentropy:  0.1293 - auc:  0.7472 - val_binary_crossentropy:  0.1284 - val_auc:  0.7335
# Epoch 10/20
# 12s - loss:  0.1287 - binary_crossentropy:  0.1287 - auc:  0.7501 - val_binary_crossentropy:  0.1290 - val_auc:  0.7317
# Epoch 11/20
# 12s - loss:  0.1282 - binary_crossentropy:  0.1282 - auc:  0.7547 - val_binary_crossentropy:  0.1286 - val_auc:  0.7304
# Epoch 12/20
# 12s - loss:  0.1278 - binary_crossentropy:  0.1278 - auc:  0.7577 - val_binary_crossentropy:  0.1280 - val_auc:  0.7348
# Epoch 13/20
# 12s - loss:  0.1272 - binary_crossentropy:  0.1272 - auc:  0.7623 - val_binary_crossentropy:  0.1288 - val_auc:  0.7308
# Epoch 14/20
# 12s - loss:  0.1266 - binary_crossentropy:  0.1266 - auc:  0.7659 - val_binary_crossentropy:  0.1281 - val_auc:  0.7358
# Epoch 15/20
# 12s - loss:  0.1261 - binary_crossentropy:  0.1261 - auc:  0.7700 - val_binary_crossentropy:  0.1279 - val_auc:  0.7388
# Epoch 16/20
# 12s - loss:  0.1255 - binary_crossentropy:  0.1255 - auc:  0.7728 - val_binary_crossentropy:  0.1284 - val_auc:  0.7343
# Epoch 17/20
# 12s - loss:  0.1250 - binary_crossentropy:  0.1250 - auc:  0.7775 - val_binary_crossentropy:  0.1282 - val_auc:  0.7407
# Epoch 18/20
# 12s - loss:  0.1244 - binary_crossentropy:  0.1244 - auc:  0.7803 - val_binary_crossentropy:  0.1287 - val_auc:  0.7421
# Epoch 19/20
# 12s - loss:  0.1239 - binary_crossentropy:  0.1239 - auc:  0.7830 - val_binary_crossentropy:  0.1287 - val_auc:  0.7381
# Epoch 20/20
# 12s - loss:  0.1233 - binary_crossentropy:  0.1233 - auc:  0.7869 - val_binary_crossentropy:  0.1287 - val_auc:  0.7345
#
# test LogLoss 0.1311
# test AUC 0.7339
# test RIG 0.074

# %% [markdown]
# # Activation Function 비교

# %% [markdown]
# 기존 ReLU : `test LogLoss 0.1311`, `test AUC 0.7339`, `test RIG 0.074`
# Mish : `test LogLoss 0.1311`, `test AUC 0.7402`, `test RIG 0.0737`
# Swish : `test LogLoss 0.1309`, `test AUC 0.7379`, `test RIG 0.075`
# Tanh
# Sigmoid
# Linear
# PReLU

# %% [markdown]
# ## Mish

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='mish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# Mish activation
# Mish activation
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 17s - loss:  0.1487 - binary_crossentropy:  0.1480 - auc:  0.6744 - val_binary_crossentropy:  0.1326 - val_auc:  0.6850
# Epoch 2/20
# 17s - loss:  0.1347 - binary_crossentropy:  0.1347 - auc:  0.6994 - val_binary_crossentropy:  0.1317 - val_auc:  0.6992
# Epoch 3/20
# 17s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7080 - val_binary_crossentropy:  0.1316 - val_auc:  0.7031
# Epoch 4/20
# 17s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7120 - val_binary_crossentropy:  0.1305 - val_auc:  0.7098
# Epoch 5/20
# 16s - loss:  0.1324 - binary_crossentropy:  0.1324 - auc:  0.7213 - val_binary_crossentropy:  0.1300 - val_auc:  0.7187
# Epoch 6/20
# 17s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7272 - val_binary_crossentropy:  0.1298 - val_auc:  0.7199
# Epoch 7/20
# 17s - loss:  0.1312 - binary_crossentropy:  0.1312 - auc:  0.7318 - val_binary_crossentropy:  0.1302 - val_auc:  0.7169
# Epoch 8/20
# 17s - loss:  0.1309 - binary_crossentropy:  0.1307 - auc:  0.7359 - val_binary_crossentropy:  0.1289 - val_auc:  0.7278
# Epoch 9/20
# 17s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7405 - val_binary_crossentropy:  0.1292 - val_auc:  0.7296
# Epoch 10/20
# 17s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7442 - val_binary_crossentropy:  0.1281 - val_auc:  0.7331
# Epoch 11/20
# 17s - loss:  0.1296 - binary_crossentropy:  0.1293 - auc:  0.7480 - val_binary_crossentropy:  0.1289 - val_auc:  0.7329
# Epoch 12/20
# 17s - loss:  0.1286 - binary_crossentropy:  0.1286 - auc:  0.7524 - val_binary_crossentropy:  0.1287 - val_auc:  0.7325
# Epoch 13/20
# 17s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7553 - val_binary_crossentropy:  0.1284 - val_auc:  0.7332
# Epoch 14/20
# 17s - loss:  0.1276 - binary_crossentropy:  0.1276 - auc:  0.7600 - val_binary_crossentropy:  0.1289 - val_auc:  0.7328
# Epoch 15/20
# 16s - loss:  0.1270 - binary_crossentropy:  0.1269 - auc:  0.7641 - val_binary_crossentropy:  0.1280 - val_auc:  0.7398
# Epoch 16/20
# 17s - loss:  0.1264 - binary_crossentropy:  0.1264 - auc:  0.7676 - val_binary_crossentropy:  0.1283 - val_auc:  0.7330
# Epoch 17/20
# 17s - loss:  0.1259 - binary_crossentropy:  0.1259 - auc:  0.7707 - val_binary_crossentropy:  0.1276 - val_auc:  0.7393
# Epoch 18/20
# 17s - loss:  0.1253 - binary_crossentropy:  0.1253 - auc:  0.7737 - val_binary_crossentropy:  0.1279 - val_auc:  0.7412
# Epoch 19/20
# 17s - loss:  0.1247 - binary_crossentropy:  0.1247 - auc:  0.7783 - val_binary_crossentropy:  0.1292 - val_auc:  0.7351
# Epoch 20/20
# 17s - loss:  0.1240 - binary_crossentropy:  0.1240 - auc:  0.7830 - val_binary_crossentropy:  0.1281 - val_auc:  0.7405
#
# test LogLoss 0.1311
# test AUC 0.7402
# test RIG 0.0737

# %% [markdown]
# ## Swish

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='swish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 13s - loss:  0.1513 - binary_crossentropy:  0.1502 - auc:  0.6731 - val_binary_crossentropy:  0.1326 - val_auc:  0.6863
# Epoch 2/20
# 13s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6987 - val_binary_crossentropy:  0.1319 - val_auc:  0.6972
# Epoch 3/20
# 12s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7087 - val_binary_crossentropy:  0.1311 - val_auc:  0.7067
# Epoch 4/20
# 12s - loss:  0.1333 - binary_crossentropy:  0.1333 - auc:  0.7136 - val_binary_crossentropy:  0.1305 - val_auc:  0.7095
# Epoch 5/20
# 12s - loss:  0.1324 - binary_crossentropy:  0.1323 - auc:  0.7217 - val_binary_crossentropy:  0.1300 - val_auc:  0.7188
# Epoch 6/20
# 12s - loss:  0.1318 - binary_crossentropy:  0.1318 - auc:  0.7277 - val_binary_crossentropy:  0.1296 - val_auc:  0.7221
# Epoch 7/20
# 12s - loss:  0.1312 - binary_crossentropy:  0.1311 - auc:  0.7321 - val_binary_crossentropy:  0.1306 - val_auc:  0.7176
# Epoch 8/20
# 12s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7366 - val_binary_crossentropy:  0.1289 - val_auc:  0.7272
# Epoch 9/20
# 12s - loss:  0.1302 - binary_crossentropy:  0.1301 - auc:  0.7399 - val_binary_crossentropy:  0.1294 - val_auc:  0.7295
# Epoch 10/20
# 12s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7442 - val_binary_crossentropy:  0.1283 - val_auc:  0.7325
# Epoch 11/20
# 12s - loss:  0.1291 - binary_crossentropy:  0.1291 - auc:  0.7479 - val_binary_crossentropy:  0.1288 - val_auc:  0.7322
# Epoch 12/20
# 13s - loss:  0.1286 - binary_crossentropy:  0.1287 - auc:  0.7524 - val_binary_crossentropy:  0.1284 - val_auc:  0.7356
# Epoch 13/20
# 13s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7558 - val_binary_crossentropy:  0.1285 - val_auc:  0.7323
# Epoch 14/20
# 14s - loss:  0.1276 - binary_crossentropy:  0.1277 - auc:  0.7600 - val_binary_crossentropy:  0.1290 - val_auc:  0.7339
# Epoch 15/20
# 14s - loss:  0.1271 - binary_crossentropy:  0.1270 - auc:  0.7635 - val_binary_crossentropy:  0.1284 - val_auc:  0.7387
# Epoch 16/20
# 12s - loss:  0.1272 - binary_crossentropy:  0.1267 - auc:  0.7669 - val_binary_crossentropy:  0.1282 - val_auc:  0.7349
# Epoch 17/20
# 12s - loss:  0.1259 - binary_crossentropy:  0.1259 - auc:  0.7710 - val_binary_crossentropy:  0.1280 - val_auc:  0.7389
# Epoch 18/20
# 13s - loss:  0.1262 - binary_crossentropy:  0.1257 - auc:  0.7743 - val_binary_crossentropy:  0.1285 - val_auc:  0.7390
# Epoch 19/20
# 12s - loss:  0.1249 - binary_crossentropy:  0.1249 - auc:  0.7774 - val_binary_crossentropy:  0.1290 - val_auc:  0.7384
# Epoch 20/20
# 12s - loss:  0.1242 - binary_crossentropy:  0.1243 - auc:  0.7820 - val_binary_crossentropy:  0.1284 - val_auc:  0.7388
#
# test LogLoss 0.1309
# test AUC 0.7379
# test RIG 0.075

# %% [markdown]
# ## tanh

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='tanh', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 12s - loss:  0.1833 - binary_crossentropy:  0.1833 - auc:  0.6371 - val_binary_crossentropy:  0.1329 - val_auc:  0.6812
# Epoch 2/20
# 12s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6976 - val_binary_crossentropy:  0.1315 - val_auc:  0.6987
# Epoch 3/20
# 12s - loss:  0.1337 - binary_crossentropy:  0.1337 - auc:  0.7089 - val_binary_crossentropy:  0.1307 - val_auc:  0.7087
# Epoch 4/20
# 12s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7156 - val_binary_crossentropy:  0.1299 - val_auc:  0.7170
# Epoch 5/20
# 12s - loss:  0.1321 - binary_crossentropy:  0.1321 - auc:  0.7228 - val_binary_crossentropy:  0.1301 - val_auc:  0.7183
# Epoch 6/20
# 12s - loss:  0.1315 - binary_crossentropy:  0.1315 - auc:  0.7285 - val_binary_crossentropy:  0.1294 - val_auc:  0.7217
# Epoch 7/20
# 12s - loss:  0.1310 - binary_crossentropy:  0.1310 - auc:  0.7324 - val_binary_crossentropy:  0.1295 - val_auc:  0.7220
# Epoch 8/20
# 12s - loss:  0.1306 - binary_crossentropy:  0.1306 - auc:  0.7369 - val_binary_crossentropy:  0.1292 - val_auc:  0.7254
# Epoch 9/20
# 12s - loss:  0.1301 - binary_crossentropy:  0.1301 - auc:  0.7404 - val_binary_crossentropy:  0.1297 - val_auc:  0.7244
# Epoch 10/20
# 12s - loss:  0.1297 - binary_crossentropy:  0.1297 - auc:  0.7439 - val_binary_crossentropy:  0.1296 - val_auc:  0.7195
# Epoch 11/20
# 12s - loss:  0.1293 - binary_crossentropy:  0.1293 - auc:  0.7457 - val_binary_crossentropy:  0.1292 - val_auc:  0.7260
# Epoch 12/20
# 12s - loss:  0.1289 - binary_crossentropy:  0.1289 - auc:  0.7500 - val_binary_crossentropy:  0.1286 - val_auc:  0.7305
# Epoch 13/20
# 12s - loss:  0.1284 - binary_crossentropy:  0.1284 - auc:  0.7527 - val_binary_crossentropy:  0.1287 - val_auc:  0.7280
# Epoch 14/20
# 12s - loss:  0.1281 - binary_crossentropy:  0.1281 - auc:  0.7563 - val_binary_crossentropy:  0.1290 - val_auc:  0.7298
# Epoch 15/20
# 12s - loss:  0.1275 - binary_crossentropy:  0.1275 - auc:  0.7599 - val_binary_crossentropy:  0.1282 - val_auc:  0.7354
# Epoch 16/20
# 12s - loss:  0.1270 - binary_crossentropy:  0.1270 - auc:  0.7640 - val_binary_crossentropy:  0.1285 - val_auc:  0.7297
# Epoch 17/20
# 12s - loss:  0.1265 - binary_crossentropy:  0.1265 - auc:  0.7673 - val_binary_crossentropy:  0.1277 - val_auc:  0.7366
# Epoch 18/20
# 12s - loss:  0.1260 - binary_crossentropy:  0.1260 - auc:  0.7701 - val_binary_crossentropy:  0.1281 - val_auc:  0.7345
# Epoch 19/20
# 12s - loss:  0.1255 - binary_crossentropy:  0.1255 - auc:  0.7731 - val_binary_crossentropy:  0.1279 - val_auc:  0.7358
# Epoch 20/20
# 12s - loss:  0.1250 - binary_crossentropy:  0.1250 - auc:  0.7775 - val_binary_crossentropy:  0.1281 - val_auc:  0.7359
#
# test LogLoss 0.1305
# test AUC 0.7382
# test RIG 0.0779

# %% [markdown]
# ## Sigmoid

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='sigmoid', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 12s - loss:  0.1450 - binary_crossentropy:  0.1449 - auc:  0.6710 - val_binary_crossentropy:  0.1328 - val_auc:  0.6793
# Epoch 2/20
# 12s - loss:  0.1356 - binary_crossentropy:  0.1356 - auc:  0.6878 - val_binary_crossentropy:  0.1324 - val_auc:  0.6858
# Epoch 3/20
# 12s - loss:  0.1349 - binary_crossentropy:  0.1349 - auc:  0.6938 - val_binary_crossentropy:  0.1319 - val_auc:  0.6932
# Epoch 4/20
# 12s - loss:  0.1343 - binary_crossentropy:  0.1343 - auc:  0.7003 - val_binary_crossentropy:  0.1314 - val_auc:  0.7013
# Epoch 5/20
# 15s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7050 - val_binary_crossentropy:  0.1309 - val_auc:  0.7069
# Epoch 6/20
# 14s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7116 - val_binary_crossentropy:  0.1306 - val_auc:  0.7095
# Epoch 7/20
# 14s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7152 - val_binary_crossentropy:  0.1306 - val_auc:  0.7106
# Epoch 8/20
# 14s - loss:  0.1325 - binary_crossentropy:  0.1325 - auc:  0.7203 - val_binary_crossentropy:  0.1300 - val_auc:  0.7162
# Epoch 9/20
# 14s - loss:  0.1321 - binary_crossentropy:  0.1320 - auc:  0.7235 - val_binary_crossentropy:  0.1303 - val_auc:  0.7166
# Epoch 10/20
# 13s - loss:  0.1317 - binary_crossentropy:  0.1317 - auc:  0.7275 - val_binary_crossentropy:  0.1296 - val_auc:  0.7200
# Epoch 11/20
# 13s - loss:  0.1313 - binary_crossentropy:  0.1313 - auc:  0.7307 - val_binary_crossentropy:  0.1299 - val_auc:  0.7209
# Epoch 12/20
# 13s - loss:  0.1309 - binary_crossentropy:  0.1309 - auc:  0.7342 - val_binary_crossentropy:  0.1299 - val_auc:  0.7219
# Epoch 13/20
# 13s - loss:  0.1303 - binary_crossentropy:  0.1303 - auc:  0.7388 - val_binary_crossentropy:  0.1297 - val_auc:  0.7219
# Epoch 14/20
# 12s - loss:  0.1297 - binary_crossentropy:  0.1298 - auc:  0.7438 - val_binary_crossentropy:  0.1293 - val_auc:  0.7262
# Epoch 15/20
# 12s - loss:  0.1292 - binary_crossentropy:  0.1291 - auc:  0.7486 - val_binary_crossentropy:  0.1289 - val_auc:  0.7298
# Epoch 16/20
# 12s - loss:  0.1285 - binary_crossentropy:  0.1285 - auc:  0.7532 - val_binary_crossentropy:  0.1289 - val_auc:  0.7280
# Epoch 17/20
# 12s - loss:  0.1278 - binary_crossentropy:  0.1278 - auc:  0.7583 - val_binary_crossentropy:  0.1281 - val_auc:  0.7339
# Epoch 18/20
# 12s - loss:  0.1272 - binary_crossentropy:  0.1272 - auc:  0.7620 - val_binary_crossentropy:  0.1282 - val_auc:  0.7336
# Epoch 19/20
# 12s - loss:  0.1266 - binary_crossentropy:  0.1266 - auc:  0.7661 - val_binary_crossentropy:  0.1279 - val_auc:  0.7367
# Epoch 20/20
# 12s - loss:  0.1258 - binary_crossentropy:  0.1258 - auc:  0.7721 - val_binary_crossentropy:  0.1285 - val_auc:  0.7341
#
# test LogLoss 0.1305
# test AUC 0.7389
# test RIG 0.0778

# %% [markdown]
# ## Linear

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='linear', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 12s - loss:  0.2098 - binary_crossentropy:  0.1991 - auc:  0.6487 - val_binary_crossentropy:  0.1346 - val_auc:  0.6616
# Epoch 2/20
# 12s - loss:  0.1363 - binary_crossentropy:  0.1363 - auc:  0.6818 - val_binary_crossentropy:  0.1331 - val_auc:  0.6821
# Epoch 3/20
# 12s - loss:  0.1358 - binary_crossentropy:  0.1358 - auc:  0.6834 - val_binary_crossentropy:  0.1331 - val_auc:  0.6806
# Epoch 4/20
# 12s - loss:  0.1354 - binary_crossentropy:  0.1354 - auc:  0.6869 - val_binary_crossentropy:  0.1326 - val_auc:  0.6850
# Epoch 5/20
# 12s - loss:  0.1352 - binary_crossentropy:  0.1352 - auc:  0.6864 - val_binary_crossentropy:  0.1326 - val_auc:  0.6888
# Epoch 6/20
# 12s - loss:  0.1351 - binary_crossentropy:  0.1351 - auc:  0.6902 - val_binary_crossentropy:  0.1325 - val_auc:  0.6858
# Epoch 7/20
# 12s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6933 - val_binary_crossentropy:  0.1320 - val_auc:  0.6922
# Epoch 8/20
# 12s - loss:  0.1346 - binary_crossentropy:  0.1346 - auc:  0.6981 - val_binary_crossentropy:  0.1318 - val_auc:  0.6950
# Epoch 9/20
# 12s - loss:  0.1342 - binary_crossentropy:  0.1342 - auc:  0.7005 - val_binary_crossentropy:  0.1324 - val_auc:  0.6945
# Epoch 10/20
# 12s - loss:  0.1339 - binary_crossentropy:  0.1339 - auc:  0.7042 - val_binary_crossentropy:  0.1315 - val_auc:  0.6984
# Epoch 11/20
# 12s - loss:  0.1337 - binary_crossentropy:  0.1337 - auc:  0.7059 - val_binary_crossentropy:  0.1316 - val_auc:  0.7020
# Epoch 12/20
# 12s - loss:  0.1335 - binary_crossentropy:  0.1335 - auc:  0.7081 - val_binary_crossentropy:  0.1311 - val_auc:  0.7036
# Epoch 13/20
# 12s - loss:  0.1332 - binary_crossentropy:  0.1332 - auc:  0.7094 - val_binary_crossentropy:  0.1314 - val_auc:  0.7008
# Epoch 14/20
# 12s - loss:  0.1331 - binary_crossentropy:  0.1331 - auc:  0.7117 - val_binary_crossentropy:  0.1310 - val_auc:  0.7065
# Epoch 15/20
# 12s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7131 - val_binary_crossentropy:  0.1310 - val_auc:  0.7046
# Epoch 16/20
# 12s - loss:  0.1328 - binary_crossentropy:  0.1328 - auc:  0.7139 - val_binary_crossentropy:  0.1310 - val_auc:  0.7050
# Epoch 17/20
# 12s - loss:  0.1327 - binary_crossentropy:  0.1327 - auc:  0.7147 - val_binary_crossentropy:  0.1308 - val_auc:  0.7076
# Epoch 18/20
# 12s - loss:  0.1326 - binary_crossentropy:  0.1326 - auc:  0.7150 - val_binary_crossentropy:  0.1307 - val_auc:  0.7067
# Epoch 19/20
# 12s - loss:  0.1325 - binary_crossentropy:  0.1325 - auc:  0.7155 - val_binary_crossentropy:  0.1309 - val_auc:  0.7075
# Epoch 20/20
# 12s - loss:  0.1324 - binary_crossentropy:  0.1324 - auc:  0.7171 - val_binary_crossentropy:  0.1306 - val_auc:  0.7081
#
# test LogLoss 0.1332
# test AUC 0.7092
# test RIG 0.0589

# %% [markdown]
# ## PReLU

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='prelu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 12s - loss:  0.1436 - binary_crossentropy:  0.1436 - auc:  0.6802 - val_binary_crossentropy:  0.1320 - val_auc:  0.6931
# Epoch 2/20
# 12s - loss:  0.1344 - binary_crossentropy:  0.1344 - auc:  0.7045 - val_binary_crossentropy:  0.1313 - val_auc:  0.7046
# Epoch 3/20
# 12s - loss:  0.1335 - binary_crossentropy:  0.1335 - auc:  0.7129 - val_binary_crossentropy:  0.1312 - val_auc:  0.7082
# Epoch 4/20
# 12s - loss:  0.1328 - binary_crossentropy:  0.1328 - auc:  0.7179 - val_binary_crossentropy:  0.1300 - val_auc:  0.7167
# Epoch 5/20
# 12s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7257 - val_binary_crossentropy:  0.1298 - val_auc:  0.7202
# Epoch 6/20
# 12s - loss:  0.1314 - binary_crossentropy:  0.1314 - auc:  0.7315 - val_binary_crossentropy:  0.1297 - val_auc:  0.7198
# Epoch 7/20
# 12s - loss:  0.1308 - binary_crossentropy:  0.1308 - auc:  0.7359 - val_binary_crossentropy:  0.1296 - val_auc:  0.7245
# Epoch 8/20
# 12s - loss:  0.1303 - binary_crossentropy:  0.1303 - auc:  0.7398 - val_binary_crossentropy:  0.1288 - val_auc:  0.7264
# Epoch 9/20
# 12s - loss:  0.1297 - binary_crossentropy:  0.1297 - auc:  0.7433 - val_binary_crossentropy:  0.1290 - val_auc:  0.7319
# Epoch 10/20
# 12s - loss:  0.1292 - binary_crossentropy:  0.1292 - auc:  0.7480 - val_binary_crossentropy:  0.1288 - val_auc:  0.7309
# Epoch 11/20
# 12s - loss:  0.1288 - binary_crossentropy:  0.1288 - auc:  0.7510 - val_binary_crossentropy:  0.1292 - val_auc:  0.7342
# Epoch 12/20
# 12s - loss:  0.1284 - binary_crossentropy:  0.1284 - auc:  0.7548 - val_binary_crossentropy:  0.1290 - val_auc:  0.7320
# Epoch 13/20
# 12s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7574 - val_binary_crossentropy:  0.1290 - val_auc:  0.7301
# Epoch 14/20
# 12s - loss:  0.1276 - binary_crossentropy:  0.1275 - auc:  0.7614 - val_binary_crossentropy:  0.1288 - val_auc:  0.7339
# Epoch 15/20
# 12s - loss:  0.1268 - binary_crossentropy:  0.1268 - auc:  0.7657 - val_binary_crossentropy:  0.1289 - val_auc:  0.7371
# Epoch 16/20
# 12s - loss:  0.1264 - binary_crossentropy:  0.1263 - auc:  0.7683 - val_binary_crossentropy:  0.1287 - val_auc:  0.7321
# Epoch 17/20
# 12s - loss:  0.1259 - binary_crossentropy:  0.1260 - auc:  0.7716 - val_binary_crossentropy:  0.1282 - val_auc:  0.7365
# Epoch 18/20
# 12s - loss:  0.1254 - binary_crossentropy:  0.1255 - auc:  0.7735 - val_binary_crossentropy:  0.1286 - val_auc:  0.7380
# Epoch 19/20
# 12s - loss:  0.1249 - binary_crossentropy:  0.1249 - auc:  0.7777 - val_binary_crossentropy:  0.1287 - val_auc:  0.7383
# Epoch 20/20
# 12s - loss:  0.1244 - binary_crossentropy:  0.1244 - auc:  0.7813 - val_binary_crossentropy:  0.1291 - val_auc:  0.7346
#
# test LogLoss 0.1315
# test AUC 0.7371
# test RIG 0.0709

# %% [markdown]
# # Epoch 50

# %% [markdown]
# ## Mish

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='mish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 12s - loss:  0.1487 - binary_crossentropy:  0.1480 - auc:  0.6744 - val_binary_crossentropy:  0.1326 - val_auc:  0.6850
# Epoch 2/50
# 12s - loss:  0.1347 - binary_crossentropy:  0.1347 - auc:  0.6993 - val_binary_crossentropy:  0.1317 - val_auc:  0.6987
# Epoch 3/50
# 12s - loss:  0.1339 - binary_crossentropy:  0.1339 - auc:  0.7079 - val_binary_crossentropy:  0.1314 - val_auc:  0.7035
# Epoch 4/50
# 12s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7122 - val_binary_crossentropy:  0.1305 - val_auc:  0.7099
# Epoch 5/50
# 12s - loss:  0.1324 - binary_crossentropy:  0.1324 - auc:  0.7211 - val_binary_crossentropy:  0.1299 - val_auc:  0.7192
# Epoch 6/50
# 12s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7272 - val_binary_crossentropy:  0.1298 - val_auc:  0.7200
# Epoch 7/50
# 12s - loss:  0.1311 - binary_crossentropy:  0.1311 - auc:  0.7317 - val_binary_crossentropy:  0.1301 - val_auc:  0.7177
# Epoch 8/50
# 12s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7361 - val_binary_crossentropy:  0.1288 - val_auc:  0.7275
# Epoch 9/50
# 12s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7403 - val_binary_crossentropy:  0.1294 - val_auc:  0.7291
# Epoch 10/50
# 12s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7441 - val_binary_crossentropy:  0.1282 - val_auc:  0.7330
# Epoch 11/50
# 12s - loss:  0.1290 - binary_crossentropy:  0.1291 - auc:  0.7477 - val_binary_crossentropy:  0.1288 - val_auc:  0.7320
# Epoch 12/50
# 12s - loss:  0.1286 - binary_crossentropy:  0.1286 - auc:  0.7523 - val_binary_crossentropy:  0.1288 - val_auc:  0.7318
# Epoch 13/50
# 12s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7553 - val_binary_crossentropy:  0.1286 - val_auc:  0.7334
# Epoch 14/50
# 12s - loss:  0.1276 - binary_crossentropy:  0.1276 - auc:  0.7593 - val_binary_crossentropy:  0.1284 - val_auc:  0.7358
# Epoch 15/50
# 12s - loss:  0.1270 - binary_crossentropy:  0.1270 - auc:  0.7638 - val_binary_crossentropy:  0.1284 - val_auc:  0.7396
# Epoch 16/50
# 12s - loss:  0.1265 - binary_crossentropy:  0.1265 - auc:  0.7666 - val_binary_crossentropy:  0.1284 - val_auc:  0.7355
# Epoch 17/50
# 12s - loss:  0.1260 - binary_crossentropy:  0.1260 - auc:  0.7705 - val_binary_crossentropy:  0.1277 - val_auc:  0.7391
# Epoch 18/50
# 12s - loss:  0.1253 - binary_crossentropy:  0.1253 - auc:  0.7733 - val_binary_crossentropy:  0.1281 - val_auc:  0.7406
# Epoch 19/50
# 12s - loss:  0.1247 - binary_crossentropy:  0.1247 - auc:  0.7781 - val_binary_crossentropy:  0.1287 - val_auc:  0.7370
# Epoch 20/50
# 12s - loss:  0.1240 - binary_crossentropy:  0.1240 - auc:  0.7825 - val_binary_crossentropy:  0.1279 - val_auc:  0.7409
# Epoch 21/50
# 12s - loss:  0.1232 - binary_crossentropy:  0.1232 - auc:  0.7871 - val_binary_crossentropy:  0.1277 - val_auc:  0.7433
# Epoch 22/50
# 12s - loss:  0.1224 - binary_crossentropy:  0.1224 - auc:  0.7916 - val_binary_crossentropy:  0.1293 - val_auc:  0.7418
# Epoch 23/50
# 12s - loss:  0.1218 - binary_crossentropy:  0.1218 - auc:  0.7958 - val_binary_crossentropy:  0.1287 - val_auc:  0.7410
# Epoch 24/50
# 12s - loss:  0.1212 - binary_crossentropy:  0.1212 - auc:  0.7997 - val_binary_crossentropy:  0.1292 - val_auc:  0.7378
# Epoch 25/50
# 12s - loss:  0.1221 - binary_crossentropy:  0.1210 - auc:  0.8037 - val_binary_crossentropy:  0.1304 - val_auc:  0.7407
# Epoch 26/50
# 12s - loss:  0.1197 - binary_crossentropy:  0.1196 - auc:  0.8092 - val_binary_crossentropy:  0.1295 - val_auc:  0.7423
# Epoch 27/50
# 12s - loss:  0.1191 - binary_crossentropy:  0.1191 - auc:  0.8112 - val_binary_crossentropy:  0.1300 - val_auc:  0.7418
# Epoch 28/50
# 12s - loss:  0.1183 - binary_crossentropy:  0.1183 - auc:  0.8154 - val_binary_crossentropy:  0.1305 - val_auc:  0.7409
# Epoch 29/50
# 12s - loss:  0.1176 - binary_crossentropy:  0.1176 - auc:  0.8197 - val_binary_crossentropy:  0.1301 - val_auc:  0.7390
# Epoch 30/50
# 12s - loss:  0.1170 - binary_crossentropy:  0.1171 - auc:  0.8221 - val_binary_crossentropy:  0.1311 - val_auc:  0.7380
# Epoch 31/50
# 12s - loss:  0.1161 - binary_crossentropy:  0.1161 - auc:  0.8266 - val_binary_crossentropy:  0.1331 - val_auc:  0.7392
# Epoch 32/50
# 12s - loss:  0.1155 - binary_crossentropy:  0.1155 - auc:  0.8295 - val_binary_crossentropy:  0.1331 - val_auc:  0.7394
# Epoch 33/50
# 12s - loss:  0.1162 - binary_crossentropy:  0.1154 - auc:  0.8321 - val_binary_crossentropy:  0.1332 - val_auc:  0.7359
# Epoch 34/50
# 12s - loss:  0.1143 - binary_crossentropy:  0.1143 - auc:  0.8355 - val_binary_crossentropy:  0.1342 - val_auc:  0.7356
# Epoch 35/50
# 12s - loss:  0.1139 - binary_crossentropy:  0.1138 - auc:  0.8381 - val_binary_crossentropy:  0.1354 - val_auc:  0.7334
# Epoch 36/50
# 12s - loss:  0.1130 - binary_crossentropy:  0.1130 - auc:  0.8405 - val_binary_crossentropy:  0.1347 - val_auc:  0.7417
# Epoch 37/50
# 12s - loss:  0.1124 - binary_crossentropy:  0.1124 - auc:  0.8443 - val_binary_crossentropy:  0.1363 - val_auc:  0.7363
# Epoch 38/50
# 12s - loss:  0.1117 - binary_crossentropy:  0.1117 - auc:  0.8467 - val_binary_crossentropy:  0.1358 - val_auc:  0.7332
# Epoch 39/50
# 12s - loss:  0.1114 - binary_crossentropy:  0.1113 - auc:  0.8505 - val_binary_crossentropy:  0.1361 - val_auc:  0.7355
# Epoch 40/50
# 12s - loss:  0.1107 - binary_crossentropy:  0.1107 - auc:  0.8515 - val_binary_crossentropy:  0.1369 - val_auc:  0.7371
# Epoch 41/50
# 12s - loss:  0.1101 - binary_crossentropy:  0.1101 - auc:  0.8542 - val_binary_crossentropy:  0.1382 - val_auc:  0.7330
# Epoch 42/50
# 12s - loss:  0.1107 - binary_crossentropy:  0.1099 - auc:  0.8567 - val_binary_crossentropy:  0.1495 - val_auc:  0.7325
# Epoch 43/50
# 12s - loss:  0.1105 - binary_crossentropy:  0.1096 - auc:  0.8592 - val_binary_crossentropy:  0.1404 - val_auc:  0.7354
# Epoch 44/50
# 12s - loss:  0.1083 - binary_crossentropy:  0.1083 - auc:  0.8618 - val_binary_crossentropy:  0.1421 - val_auc:  0.7338
# Epoch 45/50
# 12s - loss:  0.1081 - binary_crossentropy:  0.1081 - auc:  0.8634 - val_binary_crossentropy:  0.1401 - val_auc:  0.7338
# Epoch 46/50
# 12s - loss:  0.1074 - binary_crossentropy:  0.1074 - auc:  0.8655 - val_binary_crossentropy:  0.1420 - val_auc:  0.7307
# Epoch 47/50
# 12s - loss:  0.1069 - binary_crossentropy:  0.1069 - auc:  0.8674 - val_binary_crossentropy:  0.1426 - val_auc:  0.7304
# Epoch 48/50
# 12s - loss:  0.1064 - binary_crossentropy:  0.1064 - auc:  0.8696 - val_binary_crossentropy:  0.1444 - val_auc:  0.7311
# Epoch 49/50
# 12s - loss:  0.1060 - binary_crossentropy:  0.1060 - auc:  0.8715 - val_binary_crossentropy:  0.1447 - val_auc:  0.7311
# Epoch 50/50
# 12s - loss:  0.1055 - binary_crossentropy:  0.1055 - auc:  0.8723 - val_binary_crossentropy:  0.1454 - val_auc:  0.7277
#
# test LogLoss 0.1485
# test AUC 0.7268
# test RIG -0.0488

# %% [markdown]
# ## Swish

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='swish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 12s - loss:  0.1513 - binary_crossentropy:  0.1502 - auc:  0.6731 - val_binary_crossentropy:  0.1326 - val_auc:  0.6863
# Epoch 2/50
# 12s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6987 - val_binary_crossentropy:  0.1319 - val_auc:  0.6972
# Epoch 3/50
# 12s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7087 - val_binary_crossentropy:  0.1311 - val_auc:  0.7067
# Epoch 4/50
# 12s - loss:  0.1333 - binary_crossentropy:  0.1333 - auc:  0.7136 - val_binary_crossentropy:  0.1305 - val_auc:  0.7095
# Epoch 5/50
# 12s - loss:  0.1324 - binary_crossentropy:  0.1323 - auc:  0.7217 - val_binary_crossentropy:  0.1300 - val_auc:  0.7188
# Epoch 6/50
# 12s - loss:  0.1318 - binary_crossentropy:  0.1318 - auc:  0.7277 - val_binary_crossentropy:  0.1296 - val_auc:  0.7221
# Epoch 7/50
# 12s - loss:  0.1312 - binary_crossentropy:  0.1311 - auc:  0.7321 - val_binary_crossentropy:  0.1306 - val_auc:  0.7176
# Epoch 8/50
# 12s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7366 - val_binary_crossentropy:  0.1289 - val_auc:  0.7272
# Epoch 9/50
# 12s - loss:  0.1302 - binary_crossentropy:  0.1301 - auc:  0.7399 - val_binary_crossentropy:  0.1294 - val_auc:  0.7295
# Epoch 10/50
# 12s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7442 - val_binary_crossentropy:  0.1283 - val_auc:  0.7325
# Epoch 11/50
# 12s - loss:  0.1291 - binary_crossentropy:  0.1291 - auc:  0.7479 - val_binary_crossentropy:  0.1288 - val_auc:  0.7322
# Epoch 12/50
# 12s - loss:  0.1286 - binary_crossentropy:  0.1287 - auc:  0.7524 - val_binary_crossentropy:  0.1284 - val_auc:  0.7356
# Epoch 13/50
# 12s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7558 - val_binary_crossentropy:  0.1285 - val_auc:  0.7323
# Epoch 14/50
# 12s - loss:  0.1276 - binary_crossentropy:  0.1277 - auc:  0.7600 - val_binary_crossentropy:  0.1290 - val_auc:  0.7339
# Epoch 15/50
# 12s - loss:  0.1271 - binary_crossentropy:  0.1270 - auc:  0.7635 - val_binary_crossentropy:  0.1284 - val_auc:  0.7387
# Epoch 16/50
# 12s - loss:  0.1272 - binary_crossentropy:  0.1267 - auc:  0.7669 - val_binary_crossentropy:  0.1282 - val_auc:  0.7349
# Epoch 17/50
# 12s - loss:  0.1259 - binary_crossentropy:  0.1259 - auc:  0.7710 - val_binary_crossentropy:  0.1280 - val_auc:  0.7389
# Epoch 18/50
# 12s - loss:  0.1262 - binary_crossentropy:  0.1257 - auc:  0.7743 - val_binary_crossentropy:  0.1285 - val_auc:  0.7390
# Epoch 19/50
# 12s - loss:  0.1249 - binary_crossentropy:  0.1249 - auc:  0.7774 - val_binary_crossentropy:  0.1290 - val_auc:  0.7384
# Epoch 20/50
# 12s - loss:  0.1242 - binary_crossentropy:  0.1243 - auc:  0.7820 - val_binary_crossentropy:  0.1284 - val_auc:  0.7388
# Epoch 21/50
# 12s - loss:  0.1235 - binary_crossentropy:  0.1235 - auc:  0.7851 - val_binary_crossentropy:  0.1279 - val_auc:  0.7431
# Epoch 22/50
# 12s - loss:  0.1227 - binary_crossentropy:  0.1227 - auc:  0.7901 - val_binary_crossentropy:  0.1301 - val_auc:  0.7409
# Epoch 23/50
# 12s - loss:  0.1223 - binary_crossentropy:  0.1223 - auc:  0.7937 - val_binary_crossentropy:  0.1284 - val_auc:  0.7438
# Epoch 24/50
# 12s - loss:  0.1214 - binary_crossentropy:  0.1214 - auc:  0.7986 - val_binary_crossentropy:  0.1294 - val_auc:  0.7392
# Epoch 25/50
# 12s - loss:  0.1208 - binary_crossentropy:  0.1208 - auc:  0.8017 - val_binary_crossentropy:  0.1310 - val_auc:  0.7396
# Epoch 26/50
# 12s - loss:  0.1200 - binary_crossentropy:  0.1200 - auc:  0.8061 - val_binary_crossentropy:  0.1293 - val_auc:  0.7412
# Epoch 27/50
# 12s - loss:  0.1194 - binary_crossentropy:  0.1194 - auc:  0.8094 - val_binary_crossentropy:  0.1302 - val_auc:  0.7407
# Epoch 28/50
# 12s - loss:  0.1187 - binary_crossentropy:  0.1187 - auc:  0.8132 - val_binary_crossentropy:  0.1315 - val_auc:  0.7405
# Epoch 29/50
# 12s - loss:  0.1180 - binary_crossentropy:  0.1180 - auc:  0.8179 - val_binary_crossentropy:  0.1305 - val_auc:  0.7393
# Epoch 30/50
# 12s - loss:  0.1174 - binary_crossentropy:  0.1174 - auc:  0.8210 - val_binary_crossentropy:  0.1328 - val_auc:  0.7341
# Epoch 31/50
# 12s - loss:  0.1166 - binary_crossentropy:  0.1166 - auc:  0.8239 - val_binary_crossentropy:  0.1332 - val_auc:  0.7377
# Epoch 32/50
# 12s - loss:  0.1159 - binary_crossentropy:  0.1159 - auc:  0.8280 - val_binary_crossentropy:  0.1323 - val_auc:  0.7408
# Epoch 33/50
# 12s - loss:  0.1154 - binary_crossentropy:  0.1154 - auc:  0.8309 - val_binary_crossentropy:  0.1331 - val_auc:  0.7374
# Epoch 34/50
# 12s - loss:  0.1146 - binary_crossentropy:  0.1146 - auc:  0.8349 - val_binary_crossentropy:  0.1338 - val_auc:  0.7387
# Epoch 35/50
# 12s - loss:  0.1140 - binary_crossentropy:  0.1140 - auc:  0.8373 - val_binary_crossentropy:  0.1349 - val_auc:  0.7360
# Epoch 36/50
# 12s - loss:  0.1134 - binary_crossentropy:  0.1134 - auc:  0.8392 - val_binary_crossentropy:  0.1353 - val_auc:  0.7408
# Epoch 37/50
# 12s - loss:  0.1127 - binary_crossentropy:  0.1127 - auc:  0.8430 - val_binary_crossentropy:  0.1364 - val_auc:  0.7360
# Epoch 38/50
# 12s - loss:  0.1121 - binary_crossentropy:  0.1121 - auc:  0.8455 - val_binary_crossentropy:  0.1357 - val_auc:  0.7356
# Epoch 39/50
# 12s - loss:  0.1115 - binary_crossentropy:  0.1115 - auc:  0.8488 - val_binary_crossentropy:  0.1377 - val_auc:  0.7366
# Epoch 40/50
# 12s - loss:  0.1110 - binary_crossentropy:  0.1110 - auc:  0.8504 - val_binary_crossentropy:  0.1368 - val_auc:  0.7395
# Epoch 41/50
# 12s - loss:  0.1103 - binary_crossentropy:  0.1103 - auc:  0.8538 - val_binary_crossentropy:  0.1378 - val_auc:  0.7337
# Epoch 42/50
# 12s - loss:  0.1098 - binary_crossentropy:  0.1098 - auc:  0.8549 - val_binary_crossentropy:  0.1388 - val_auc:  0.7344
# Epoch 43/50
# 12s - loss:  0.1105 - binary_crossentropy:  0.1096 - auc:  0.8587 - val_binary_crossentropy:  0.1395 - val_auc:  0.7348
# Epoch 44/50
# 12s - loss:  0.1087 - binary_crossentropy:  0.1087 - auc:  0.8610 - val_binary_crossentropy:  0.1398 - val_auc:  0.7347
# Epoch 45/50
# 12s - loss:  0.1081 - binary_crossentropy:  0.1081 - auc:  0.8629 - val_binary_crossentropy:  0.1400 - val_auc:  0.7342
# Epoch 46/50
# 12s - loss:  0.1075 - binary_crossentropy:  0.1075 - auc:  0.8651 - val_binary_crossentropy:  0.1405 - val_auc:  0.7313
# Epoch 47/50
# 12s - loss:  0.1071 - binary_crossentropy:  0.1071 - auc:  0.8666 - val_binary_crossentropy:  0.1431 - val_auc:  0.7278
# Epoch 48/50
# 12s - loss:  0.1064 - binary_crossentropy:  0.1064 - auc:  0.8695 - val_binary_crossentropy:  0.1442 - val_auc:  0.7275
# Epoch 49/50
# 12s - loss:  0.1060 - binary_crossentropy:  0.1060 - auc:  0.8716 - val_binary_crossentropy:  0.1423 - val_auc:  0.7294
# Epoch 50/50
# 12s - loss:  0.1056 - binary_crossentropy:  0.1056 - auc:  0.8732 - val_binary_crossentropy:  0.1433 - val_auc:  0.7271
#
# test LogLoss 0.1461
# test AUC 0.7273
# test RIG -0.0321

# %% [markdown]
# ## Tanh

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='tanh', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 12s - loss:  0.1833 - binary_crossentropy:  0.1833 - auc:  0.6371 - val_binary_crossentropy:  0.1329 - val_auc:  0.6812
# Epoch 2/50
# 12s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6976 - val_binary_crossentropy:  0.1315 - val_auc:  0.6987
# Epoch 3/50
# 12s - loss:  0.1337 - binary_crossentropy:  0.1337 - auc:  0.7089 - val_binary_crossentropy:  0.1307 - val_auc:  0.7087
# Epoch 4/50
# 12s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7156 - val_binary_crossentropy:  0.1299 - val_auc:  0.7170
# Epoch 5/50
# 12s - loss:  0.1321 - binary_crossentropy:  0.1321 - auc:  0.7228 - val_binary_crossentropy:  0.1301 - val_auc:  0.7183
# Epoch 6/50
# 12s - loss:  0.1315 - binary_crossentropy:  0.1315 - auc:  0.7285 - val_binary_crossentropy:  0.1294 - val_auc:  0.7217
# Epoch 7/50
# 12s - loss:  0.1310 - binary_crossentropy:  0.1310 - auc:  0.7324 - val_binary_crossentropy:  0.1295 - val_auc:  0.7220
# Epoch 8/50
# 12s - loss:  0.1306 - binary_crossentropy:  0.1306 - auc:  0.7369 - val_binary_crossentropy:  0.1292 - val_auc:  0.7254
# Epoch 9/50
# 12s - loss:  0.1301 - binary_crossentropy:  0.1301 - auc:  0.7404 - val_binary_crossentropy:  0.1297 - val_auc:  0.7244
# Epoch 10/50
# 12s - loss:  0.1297 - binary_crossentropy:  0.1297 - auc:  0.7439 - val_binary_crossentropy:  0.1296 - val_auc:  0.7195
# Epoch 11/50
# 12s - loss:  0.1293 - binary_crossentropy:  0.1293 - auc:  0.7457 - val_binary_crossentropy:  0.1292 - val_auc:  0.7260
# Epoch 12/50
# 12s - loss:  0.1289 - binary_crossentropy:  0.1289 - auc:  0.7500 - val_binary_crossentropy:  0.1286 - val_auc:  0.7305
# Epoch 13/50
# 12s - loss:  0.1284 - binary_crossentropy:  0.1284 - auc:  0.7527 - val_binary_crossentropy:  0.1287 - val_auc:  0.7280
# Epoch 14/50
# 12s - loss:  0.1281 - binary_crossentropy:  0.1281 - auc:  0.7563 - val_binary_crossentropy:  0.1290 - val_auc:  0.7298
# Epoch 15/50
# 12s - loss:  0.1275 - binary_crossentropy:  0.1275 - auc:  0.7599 - val_binary_crossentropy:  0.1282 - val_auc:  0.7354
# Epoch 16/50
# 12s - loss:  0.1270 - binary_crossentropy:  0.1270 - auc:  0.7640 - val_binary_crossentropy:  0.1285 - val_auc:  0.7297
# Epoch 17/50
# 12s - loss:  0.1265 - binary_crossentropy:  0.1265 - auc:  0.7673 - val_binary_crossentropy:  0.1277 - val_auc:  0.7366
# Epoch 18/50
# 12s - loss:  0.1260 - binary_crossentropy:  0.1260 - auc:  0.7701 - val_binary_crossentropy:  0.1281 - val_auc:  0.7345
# Epoch 19/50
# 12s - loss:  0.1255 - binary_crossentropy:  0.1255 - auc:  0.7731 - val_binary_crossentropy:  0.1279 - val_auc:  0.7358
# Epoch 20/50
# 12s - loss:  0.1250 - binary_crossentropy:  0.1250 - auc:  0.7775 - val_binary_crossentropy:  0.1281 - val_auc:  0.7359
# Epoch 21/50
# 12s - loss:  0.1245 - binary_crossentropy:  0.1245 - auc:  0.7793 - val_binary_crossentropy:  0.1279 - val_auc:  0.7361
# Epoch 22/50
# 12s - loss:  0.1238 - binary_crossentropy:  0.1238 - auc:  0.7849 - val_binary_crossentropy:  0.1286 - val_auc:  0.7373
# Epoch 23/50
# 12s - loss:  0.1236 - binary_crossentropy:  0.1236 - auc:  0.7868 - val_binary_crossentropy:  0.1286 - val_auc:  0.7372
# Epoch 24/50
# 12s - loss:  0.1229 - binary_crossentropy:  0.1229 - auc:  0.7913 - val_binary_crossentropy:  0.1281 - val_auc:  0.7356
# Epoch 25/50
# 12s - loss:  0.1224 - binary_crossentropy:  0.1225 - auc:  0.7921 - val_binary_crossentropy:  0.1283 - val_auc:  0.7387
# Epoch 26/50
# 12s - loss:  0.1219 - binary_crossentropy:  0.1219 - auc:  0.7974 - val_binary_crossentropy:  0.1284 - val_auc:  0.7382
# Epoch 27/50
# 12s - loss:  0.1217 - binary_crossentropy:  0.1217 - auc:  0.7976 - val_binary_crossentropy:  0.1291 - val_auc:  0.7336
# Epoch 28/50
# 12s - loss:  0.1211 - binary_crossentropy:  0.1211 - auc:  0.8018 - val_binary_crossentropy:  0.1292 - val_auc:  0.7353
# Epoch 29/50
# 12s - loss:  0.1206 - binary_crossentropy:  0.1206 - auc:  0.8058 - val_binary_crossentropy:  0.1294 - val_auc:  0.7359
# Epoch 30/50
# 12s - loss:  0.1203 - binary_crossentropy:  0.1203 - auc:  0.8064 - val_binary_crossentropy:  0.1294 - val_auc:  0.7352
# Epoch 31/50
# 12s - loss:  0.1197 - binary_crossentropy:  0.1197 - auc:  0.8100 - val_binary_crossentropy:  0.1294 - val_auc:  0.7363
# Epoch 32/50
# 12s - loss:  0.1192 - binary_crossentropy:  0.1192 - auc:  0.8123 - val_binary_crossentropy:  0.1297 - val_auc:  0.7345
# Epoch 33/50
# 12s - loss:  0.1188 - binary_crossentropy:  0.1188 - auc:  0.8149 - val_binary_crossentropy:  0.1303 - val_auc:  0.7345
# Epoch 34/50
# 12s - loss:  0.1184 - binary_crossentropy:  0.1183 - auc:  0.8170 - val_binary_crossentropy:  0.1300 - val_auc:  0.7326
# Epoch 35/50
# 12s - loss:  0.1181 - binary_crossentropy:  0.1180 - auc:  0.8175 - val_binary_crossentropy:  0.1305 - val_auc:  0.7316
# Epoch 36/50
# 12s - loss:  0.1176 - binary_crossentropy:  0.1176 - auc:  0.8203 - val_binary_crossentropy:  0.1305 - val_auc:  0.7368
# Epoch 37/50
# 12s - loss:  0.1171 - binary_crossentropy:  0.1171 - auc:  0.8242 - val_binary_crossentropy:  0.1307 - val_auc:  0.7346
# Epoch 38/50
# 12s - loss:  0.1168 - binary_crossentropy:  0.1168 - auc:  0.8245 - val_binary_crossentropy:  0.1301 - val_auc:  0.7367
# Epoch 39/50
# 12s - loss:  0.1164 - binary_crossentropy:  0.1164 - auc:  0.8276 - val_binary_crossentropy:  0.1308 - val_auc:  0.7351
# Epoch 40/50
# 12s - loss:  0.1159 - binary_crossentropy:  0.1159 - auc:  0.8295 - val_binary_crossentropy:  0.1311 - val_auc:  0.7323
# Epoch 41/50
# 12s - loss:  0.1155 - binary_crossentropy:  0.1155 - auc:  0.8321 - val_binary_crossentropy:  0.1310 - val_auc:  0.7359
# Epoch 42/50
# 12s - loss:  0.1150 - binary_crossentropy:  0.1150 - auc:  0.8338 - val_binary_crossentropy:  0.1318 - val_auc:  0.7323
# Epoch 43/50
# 12s - loss:  0.1146 - binary_crossentropy:  0.1146 - auc:  0.8357 - val_binary_crossentropy:  0.1328 - val_auc:  0.7340
# Epoch 44/50
# 12s - loss:  0.1142 - binary_crossentropy:  0.1142 - auc:  0.8379 - val_binary_crossentropy:  0.1323 - val_auc:  0.7318
# Epoch 45/50
# 12s - loss:  0.1139 - binary_crossentropy:  0.1139 - auc:  0.8396 - val_binary_crossentropy:  0.1328 - val_auc:  0.7333
# Epoch 46/50
# 12s - loss:  0.1132 - binary_crossentropy:  0.1132 - auc:  0.8429 - val_binary_crossentropy:  0.1326 - val_auc:  0.7327
# Epoch 47/50
# 12s - loss:  0.1131 - binary_crossentropy:  0.1131 - auc:  0.8422 - val_binary_crossentropy:  0.1326 - val_auc:  0.7310
# Epoch 48/50
# 12s - loss:  0.1127 - binary_crossentropy:  0.1127 - auc:  0.8454 - val_binary_crossentropy:  0.1334 - val_auc:  0.7303
# Epoch 49/50
# 12s - loss:  0.1125 - binary_crossentropy:  0.1125 - auc:  0.8464 - val_binary_crossentropy:  0.1338 - val_auc:  0.7288
# Epoch 50/50
# 12s - loss:  0.1121 - binary_crossentropy:  0.1121 - auc:  0.8475 - val_binary_crossentropy:  0.1336 - val_auc:  0.7339
#
# test LogLoss 0.1366
# test AUC 0.7319
# test RIG 0.0352

# %% [markdown]
# ## ReLU

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 12s - loss:  0.1408 - binary_crossentropy:  0.1408 - auc:  0.6813 - val_binary_crossentropy:  0.1321 - val_auc:  0.6948
# Epoch 2/50
# 12s - loss:  0.1341 - binary_crossentropy:  0.1341 - auc:  0.7073 - val_binary_crossentropy:  0.1313 - val_auc:  0.7070
# Epoch 3/50
# 12s - loss:  0.1330 - binary_crossentropy:  0.1331 - auc:  0.7173 - val_binary_crossentropy:  0.1306 - val_auc:  0.7112
# Epoch 4/50
# 12s - loss:  0.1323 - binary_crossentropy:  0.1323 - auc:  0.7226 - val_binary_crossentropy:  0.1295 - val_auc:  0.7210
# Epoch 5/50
# 12s - loss:  0.1314 - binary_crossentropy:  0.1314 - auc:  0.7304 - val_binary_crossentropy:  0.1293 - val_auc:  0.7244
# Epoch 6/50
# 12s - loss:  0.1310 - binary_crossentropy:  0.1310 - auc:  0.7349 - val_binary_crossentropy:  0.1295 - val_auc:  0.7223
# Epoch 7/50
# 12s - loss:  0.1304 - binary_crossentropy:  0.1304 - auc:  0.7390 - val_binary_crossentropy:  0.1297 - val_auc:  0.7227
# Epoch 8/50
# 12s - loss:  0.1298 - binary_crossentropy:  0.1298 - auc:  0.7433 - val_binary_crossentropy:  0.1285 - val_auc:  0.7314
# Epoch 9/50
# 12s - loss:  0.1292 - binary_crossentropy:  0.1292 - auc:  0.7469 - val_binary_crossentropy:  0.1288 - val_auc:  0.7339
# Epoch 10/50
# 12s - loss:  0.1288 - binary_crossentropy:  0.1288 - auc:  0.7509 - val_binary_crossentropy:  0.1281 - val_auc:  0.7352
# Epoch 11/50
# 12s - loss:  0.1282 - binary_crossentropy:  0.1283 - auc:  0.7538 - val_binary_crossentropy:  0.1285 - val_auc:  0.7368
# Epoch 12/50
# 12s - loss:  0.1277 - binary_crossentropy:  0.1278 - auc:  0.7590 - val_binary_crossentropy:  0.1285 - val_auc:  0.7348
# Epoch 13/50
# 12s - loss:  0.1273 - binary_crossentropy:  0.1273 - auc:  0.7606 - val_binary_crossentropy:  0.1284 - val_auc:  0.7356
# Epoch 14/50
# 12s - loss:  0.1269 - binary_crossentropy:  0.1269 - auc:  0.7650 - val_binary_crossentropy:  0.1285 - val_auc:  0.7358
# Epoch 15/50
# 12s - loss:  0.1264 - binary_crossentropy:  0.1264 - auc:  0.7686 - val_binary_crossentropy:  0.1281 - val_auc:  0.7415
# Epoch 16/50
# 12s - loss:  0.1259 - binary_crossentropy:  0.1259 - auc:  0.7708 - val_binary_crossentropy:  0.1283 - val_auc:  0.7353
# Epoch 17/50
# 12s - loss:  0.1254 - binary_crossentropy:  0.1255 - auc:  0.7742 - val_binary_crossentropy:  0.1279 - val_auc:  0.7380
# Epoch 18/50
# 12s - loss:  0.1249 - binary_crossentropy:  0.1249 - auc:  0.7761 - val_binary_crossentropy:  0.1288 - val_auc:  0.7403
# Epoch 19/50
# 12s - loss:  0.1244 - binary_crossentropy:  0.1244 - auc:  0.7808 - val_binary_crossentropy:  0.1288 - val_auc:  0.7395
# Epoch 20/50
# 12s - loss:  0.1240 - binary_crossentropy:  0.1241 - auc:  0.7834 - val_binary_crossentropy:  0.1285 - val_auc:  0.7409
# Epoch 21/50
# 12s - loss:  0.1234 - binary_crossentropy:  0.1234 - auc:  0.7859 - val_binary_crossentropy:  0.1279 - val_auc:  0.7458
# Epoch 22/50
# 12s - loss:  0.1229 - binary_crossentropy:  0.1229 - auc:  0.7891 - val_binary_crossentropy:  0.1298 - val_auc:  0.7420
# Epoch 23/50
# 12s - loss:  0.1224 - binary_crossentropy:  0.1224 - auc:  0.7926 - val_binary_crossentropy:  0.1287 - val_auc:  0.7414
# Epoch 24/50
# 12s - loss:  0.1220 - binary_crossentropy:  0.1220 - auc:  0.7952 - val_binary_crossentropy:  0.1295 - val_auc:  0.7381
# Epoch 25/50
# 12s - loss:  0.1214 - binary_crossentropy:  0.1214 - auc:  0.7981 - val_binary_crossentropy:  0.1296 - val_auc:  0.7434
# Epoch 26/50
# 12s - loss:  0.1208 - binary_crossentropy:  0.1208 - auc:  0.8020 - val_binary_crossentropy:  0.1298 - val_auc:  0.7417
# Epoch 27/50
# 12s - loss:  0.1204 - binary_crossentropy:  0.1204 - auc:  0.8034 - val_binary_crossentropy:  0.1302 - val_auc:  0.7401
# Epoch 28/50
# 12s - loss:  0.1200 - binary_crossentropy:  0.1199 - auc:  0.8066 - val_binary_crossentropy:  0.1309 - val_auc:  0.7424
# Epoch 29/50
# 12s - loss:  0.1195 - binary_crossentropy:  0.1195 - auc:  0.8095 - val_binary_crossentropy:  0.1310 - val_auc:  0.7437
# Epoch 30/50
# 12s - loss:  0.1189 - binary_crossentropy:  0.1189 - auc:  0.8130 - val_binary_crossentropy:  0.1320 - val_auc:  0.7369
# Epoch 31/50
# 12s - loss:  0.1183 - binary_crossentropy:  0.1183 - auc:  0.8151 - val_binary_crossentropy:  0.1318 - val_auc:  0.7386
# Epoch 32/50
# 12s - loss:  0.1178 - binary_crossentropy:  0.1178 - auc:  0.8185 - val_binary_crossentropy:  0.1318 - val_auc:  0.7417
# Epoch 33/50
# 12s - loss:  0.1173 - binary_crossentropy:  0.1173 - auc:  0.8210 - val_binary_crossentropy:  0.1322 - val_auc:  0.7390
# Epoch 34/50
# 12s - loss:  0.1171 - binary_crossentropy:  0.1171 - auc:  0.8217 - val_binary_crossentropy:  0.1327 - val_auc:  0.7390
# Epoch 35/50
# 12s - loss:  0.1164 - binary_crossentropy:  0.1164 - auc:  0.8249 - val_binary_crossentropy:  0.1345 - val_auc:  0.7340
# Epoch 36/50
# 12s - loss:  0.1161 - binary_crossentropy:  0.1161 - auc:  0.8261 - val_binary_crossentropy:  0.1342 - val_auc:  0.7403
# Epoch 37/50
# 12s - loss:  0.1156 - binary_crossentropy:  0.1156 - auc:  0.8293 - val_binary_crossentropy:  0.1341 - val_auc:  0.7404
# Epoch 38/50
# 12s - loss:  0.1151 - binary_crossentropy:  0.1151 - auc:  0.8309 - val_binary_crossentropy:  0.1334 - val_auc:  0.7383
# Epoch 39/50
# 12s - loss:  0.1147 - binary_crossentropy:  0.1147 - auc:  0.8346 - val_binary_crossentropy:  0.1343 - val_auc:  0.7405
# Epoch 40/50
# 12s - loss:  0.1145 - binary_crossentropy:  0.1144 - auc:  0.8348 - val_binary_crossentropy:  0.1357 - val_auc:  0.7367
# Epoch 41/50
# 12s - loss:  0.1140 - binary_crossentropy:  0.1140 - auc:  0.8365 - val_binary_crossentropy:  0.1367 - val_auc:  0.7359
# Epoch 42/50
# 12s - loss:  0.1135 - binary_crossentropy:  0.1135 - auc:  0.8396 - val_binary_crossentropy:  0.1369 - val_auc:  0.7371
# Epoch 43/50
# 12s - loss:  0.1130 - binary_crossentropy:  0.1130 - auc:  0.8413 - val_binary_crossentropy:  0.1370 - val_auc:  0.7376
# Epoch 44/50
# 12s - loss:  0.1129 - binary_crossentropy:  0.1127 - auc:  0.8422 - val_binary_crossentropy:  0.1373 - val_auc:  0.7371
# Epoch 45/50
# 12s - loss:  0.1124 - binary_crossentropy:  0.1123 - auc:  0.8447 - val_binary_crossentropy:  0.1385 - val_auc:  0.7358
# Epoch 46/50
# 12s - loss:  0.1119 - binary_crossentropy:  0.1119 - auc:  0.8462 - val_binary_crossentropy:  0.1389 - val_auc:  0.7311
# Epoch 47/50
# 12s - loss:  0.1116 - binary_crossentropy:  0.1116 - auc:  0.8476 - val_binary_crossentropy:  0.1396 - val_auc:  0.7340
# Epoch 48/50
# 12s - loss:  0.1112 - binary_crossentropy:  0.1113 - auc:  0.8498 - val_binary_crossentropy:  0.1409 - val_auc:  0.7330
# Epoch 49/50
# 12s - loss:  0.1110 - binary_crossentropy:  0.1110 - auc:  0.8506 - val_binary_crossentropy:  0.1410 - val_auc:  0.7337
# Epoch 50/50
# 12s - loss:  0.1105 - binary_crossentropy:  0.1106 - auc:  0.8526 - val_binary_crossentropy:  0.1403 - val_auc:  0.7339
#
# test LogLoss 0.1433
# test AUC 0.7329
# test RIG -0.0127

# %% [markdown]
# ## Sigmoid

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='sigmoid', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 12s - loss:  0.1450 - binary_crossentropy:  0.1449 - auc:  0.6710 - val_binary_crossentropy:  0.1328 - val_auc:  0.6793
# Epoch 2/50
# 12s - loss:  0.1356 - binary_crossentropy:  0.1356 - auc:  0.6878 - val_binary_crossentropy:  0.1324 - val_auc:  0.6858
# Epoch 3/50
# 12s - loss:  0.1349 - binary_crossentropy:  0.1349 - auc:  0.6938 - val_binary_crossentropy:  0.1319 - val_auc:  0.6932
# Epoch 4/50
# 12s - loss:  0.1343 - binary_crossentropy:  0.1343 - auc:  0.7003 - val_binary_crossentropy:  0.1314 - val_auc:  0.7013
# Epoch 5/50
# 12s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7050 - val_binary_crossentropy:  0.1309 - val_auc:  0.7069
# Epoch 6/50
# 12s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7116 - val_binary_crossentropy:  0.1306 - val_auc:  0.7095
# Epoch 7/50
# 12s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7152 - val_binary_crossentropy:  0.1306 - val_auc:  0.7106
# Epoch 8/50
# 12s - loss:  0.1325 - binary_crossentropy:  0.1325 - auc:  0.7203 - val_binary_crossentropy:  0.1300 - val_auc:  0.7162
# Epoch 9/50
# 12s - loss:  0.1321 - binary_crossentropy:  0.1320 - auc:  0.7235 - val_binary_crossentropy:  0.1303 - val_auc:  0.7166
# Epoch 10/50
# 12s - loss:  0.1317 - binary_crossentropy:  0.1317 - auc:  0.7275 - val_binary_crossentropy:  0.1296 - val_auc:  0.7200
# Epoch 11/50
# 12s - loss:  0.1313 - binary_crossentropy:  0.1313 - auc:  0.7307 - val_binary_crossentropy:  0.1299 - val_auc:  0.7209
# Epoch 12/50
# 12s - loss:  0.1309 - binary_crossentropy:  0.1309 - auc:  0.7342 - val_binary_crossentropy:  0.1299 - val_auc:  0.7219
# Epoch 13/50
# 12s - loss:  0.1303 - binary_crossentropy:  0.1303 - auc:  0.7388 - val_binary_crossentropy:  0.1297 - val_auc:  0.7219
# Epoch 14/50
# 12s - loss:  0.1297 - binary_crossentropy:  0.1298 - auc:  0.7438 - val_binary_crossentropy:  0.1293 - val_auc:  0.7262
# Epoch 15/50
# 12s - loss:  0.1292 - binary_crossentropy:  0.1291 - auc:  0.7486 - val_binary_crossentropy:  0.1289 - val_auc:  0.7298
# Epoch 16/50
# 12s - loss:  0.1285 - binary_crossentropy:  0.1285 - auc:  0.7532 - val_binary_crossentropy:  0.1289 - val_auc:  0.7280
# Epoch 17/50
# 12s - loss:  0.1278 - binary_crossentropy:  0.1278 - auc:  0.7583 - val_binary_crossentropy:  0.1281 - val_auc:  0.7339
# Epoch 18/50
# 12s - loss:  0.1272 - binary_crossentropy:  0.1272 - auc:  0.7620 - val_binary_crossentropy:  0.1282 - val_auc:  0.7336
# Epoch 19/50
# 12s - loss:  0.1266 - binary_crossentropy:  0.1266 - auc:  0.7661 - val_binary_crossentropy:  0.1279 - val_auc:  0.7367
# Epoch 20/50
# 12s - loss:  0.1258 - binary_crossentropy:  0.1258 - auc:  0.7721 - val_binary_crossentropy:  0.1285 - val_auc:  0.7341
# Epoch 21/50
# 12s - loss:  0.1252 - binary_crossentropy:  0.1252 - auc:  0.7758 - val_binary_crossentropy:  0.1282 - val_auc:  0.7377
# Epoch 22/50
# 12s - loss:  0.1244 - binary_crossentropy:  0.1244 - auc:  0.7795 - val_binary_crossentropy:  0.1288 - val_auc:  0.7342
# Epoch 23/50
# 12s - loss:  0.1239 - binary_crossentropy:  0.1239 - auc:  0.7839 - val_binary_crossentropy:  0.1291 - val_auc:  0.7359
# Epoch 24/50
# 12s - loss:  0.1233 - binary_crossentropy:  0.1233 - auc:  0.7879 - val_binary_crossentropy:  0.1291 - val_auc:  0.7362
# Epoch 25/50
# 12s - loss:  0.1226 - binary_crossentropy:  0.1227 - auc:  0.7909 - val_binary_crossentropy:  0.1288 - val_auc:  0.7382
# Epoch 26/50
# 12s - loss:  0.1221 - binary_crossentropy:  0.1221 - auc:  0.7957 - val_binary_crossentropy:  0.1293 - val_auc:  0.7364
# Epoch 27/50
# 12s - loss:  0.1215 - binary_crossentropy:  0.1215 - auc:  0.7976 - val_binary_crossentropy:  0.1297 - val_auc:  0.7315
# Epoch 28/50
# 12s - loss:  0.1209 - binary_crossentropy:  0.1209 - auc:  0.8015 - val_binary_crossentropy:  0.1297 - val_auc:  0.7372
# Epoch 29/50
# 12s - loss:  0.1202 - binary_crossentropy:  0.1202 - auc:  0.8060 - val_binary_crossentropy:  0.1312 - val_auc:  0.7334
# Epoch 30/50
# 12s - loss:  0.1197 - binary_crossentropy:  0.1198 - auc:  0.8084 - val_binary_crossentropy:  0.1306 - val_auc:  0.7327
# Epoch 31/50
# 12s - loss:  0.1192 - binary_crossentropy:  0.1192 - auc:  0.8109 - val_binary_crossentropy:  0.1310 - val_auc:  0.7332
# Epoch 32/50
# 12s - loss:  0.1188 - binary_crossentropy:  0.1188 - auc:  0.8127 - val_binary_crossentropy:  0.1305 - val_auc:  0.7358
# Epoch 33/50
# 12s - loss:  0.1181 - binary_crossentropy:  0.1181 - auc:  0.8173 - val_binary_crossentropy:  0.1319 - val_auc:  0.7364
# Epoch 34/50
# 12s - loss:  0.1175 - binary_crossentropy:  0.1175 - auc:  0.8197 - val_binary_crossentropy:  0.1315 - val_auc:  0.7362
# Epoch 35/50
# 12s - loss:  0.1173 - binary_crossentropy:  0.1172 - auc:  0.8210 - val_binary_crossentropy:  0.1323 - val_auc:  0.7311
# Epoch 36/50
# 12s - loss:  0.1165 - binary_crossentropy:  0.1165 - auc:  0.8237 - val_binary_crossentropy:  0.1323 - val_auc:  0.7360
# Epoch 37/50
# 12s - loss:  0.1162 - binary_crossentropy:  0.1163 - auc:  0.8258 - val_binary_crossentropy:  0.1324 - val_auc:  0.7352
# Epoch 38/50
# 12s - loss:  0.1159 - binary_crossentropy:  0.1159 - auc:  0.8276 - val_binary_crossentropy:  0.1323 - val_auc:  0.7338
# Epoch 39/50
# 12s - loss:  0.1154 - binary_crossentropy:  0.1154 - auc:  0.8296 - val_binary_crossentropy:  0.1329 - val_auc:  0.7354
# Epoch 40/50
# 12s - loss:  0.1152 - binary_crossentropy:  0.1151 - auc:  0.8312 - val_binary_crossentropy:  0.1347 - val_auc:  0.7312
# Epoch 41/50
# 12s - loss:  0.1146 - binary_crossentropy:  0.1146 - auc:  0.8332 - val_binary_crossentropy:  0.1334 - val_auc:  0.7337
# Epoch 42/50
# 12s - loss:  0.1142 - binary_crossentropy:  0.1142 - auc:  0.8359 - val_binary_crossentropy:  0.1348 - val_auc:  0.7341
# Epoch 43/50
# 12s - loss:  0.1138 - binary_crossentropy:  0.1138 - auc:  0.8373 - val_binary_crossentropy:  0.1357 - val_auc:  0.7331
# Epoch 44/50
# 12s - loss:  0.1133 - binary_crossentropy:  0.1132 - auc:  0.8394 - val_binary_crossentropy:  0.1348 - val_auc:  0.7346
# Epoch 45/50
# 12s - loss:  0.1131 - binary_crossentropy:  0.1131 - auc:  0.8411 - val_binary_crossentropy:  0.1345 - val_auc:  0.7333
# Epoch 46/50
# 12s - loss:  0.1127 - binary_crossentropy:  0.1127 - auc:  0.8426 - val_binary_crossentropy:  0.1355 - val_auc:  0.7316
# Epoch 47/50
# 12s - loss:  0.1124 - binary_crossentropy:  0.1124 - auc:  0.8439 - val_binary_crossentropy:  0.1358 - val_auc:  0.7307
# Epoch 48/50
# 12s - loss:  0.1119 - binary_crossentropy:  0.1120 - auc:  0.8461 - val_binary_crossentropy:  0.1363 - val_auc:  0.7322
# Epoch 49/50
# 12s - loss:  0.1117 - binary_crossentropy:  0.1117 - auc:  0.8475 - val_binary_crossentropy:  0.1350 - val_auc:  0.7345
# Epoch 50/50
# 12s - loss:  0.1114 - binary_crossentropy:  0.1115 - auc:  0.8484 - val_binary_crossentropy:  0.1363 - val_auc:  0.7294
#
# test LogLoss 0.1397
# test AUC 0.7298
# test RIG 0.0127

# %% [markdown]
# # Epoch 30

# %% [markdown]
# ## Linear

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='mish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=30, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/30
# 13s - loss:  0.1487 - binary_crossentropy:  0.1480 - auc:  0.6744 - val_binary_crossentropy:  0.1326 - val_auc:  0.6850
# Epoch 2/30
# 12s - loss:  0.1347 - binary_crossentropy:  0.1347 - auc:  0.6993 - val_binary_crossentropy:  0.1317 - val_auc:  0.6987
# Epoch 3/30
# 14s - loss:  0.1339 - binary_crossentropy:  0.1339 - auc:  0.7079 - val_binary_crossentropy:  0.1314 - val_auc:  0.7035
# Epoch 4/30
# 12s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7122 - val_binary_crossentropy:  0.1305 - val_auc:  0.7099
# Epoch 5/30
# 12s - loss:  0.1324 - binary_crossentropy:  0.1324 - auc:  0.7211 - val_binary_crossentropy:  0.1299 - val_auc:  0.7192
# Epoch 6/30
# 12s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7272 - val_binary_crossentropy:  0.1298 - val_auc:  0.7200
# Epoch 7/30
# 12s - loss:  0.1311 - binary_crossentropy:  0.1311 - auc:  0.7317 - val_binary_crossentropy:  0.1301 - val_auc:  0.7177
# Epoch 8/30
# 12s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7361 - val_binary_crossentropy:  0.1288 - val_auc:  0.7275
# Epoch 9/30
# 12s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7403 - val_binary_crossentropy:  0.1294 - val_auc:  0.7291
# Epoch 10/30
# 12s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7441 - val_binary_crossentropy:  0.1282 - val_auc:  0.7330
# Epoch 11/30
# 12s - loss:  0.1290 - binary_crossentropy:  0.1291 - auc:  0.7477 - val_binary_crossentropy:  0.1288 - val_auc:  0.7320
# Epoch 12/30
# 12s - loss:  0.1286 - binary_crossentropy:  0.1286 - auc:  0.7523 - val_binary_crossentropy:  0.1288 - val_auc:  0.7318
# Epoch 13/30
# 13s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7553 - val_binary_crossentropy:  0.1286 - val_auc:  0.7334
# Epoch 14/30
# 12s - loss:  0.1276 - binary_crossentropy:  0.1276 - auc:  0.7593 - val_binary_crossentropy:  0.1284 - val_auc:  0.7358
# Epoch 15/30
# 12s - loss:  0.1270 - binary_crossentropy:  0.1270 - auc:  0.7638 - val_binary_crossentropy:  0.1284 - val_auc:  0.7396
# Epoch 16/30
# 12s - loss:  0.1265 - binary_crossentropy:  0.1265 - auc:  0.7666 - val_binary_crossentropy:  0.1284 - val_auc:  0.7355
# Epoch 17/30
# 12s - loss:  0.1260 - binary_crossentropy:  0.1260 - auc:  0.7705 - val_binary_crossentropy:  0.1277 - val_auc:  0.7391
# Epoch 18/30
# 12s - loss:  0.1253 - binary_crossentropy:  0.1253 - auc:  0.7733 - val_binary_crossentropy:  0.1281 - val_auc:  0.7406
# Epoch 19/30
# 12s - loss:  0.1247 - binary_crossentropy:  0.1247 - auc:  0.7781 - val_binary_crossentropy:  0.1287 - val_auc:  0.7370
# Epoch 20/30
# 12s - loss:  0.1240 - binary_crossentropy:  0.1240 - auc:  0.7825 - val_binary_crossentropy:  0.1279 - val_auc:  0.7409
# Epoch 21/30
# 12s - loss:  0.1232 - binary_crossentropy:  0.1232 - auc:  0.7871 - val_binary_crossentropy:  0.1277 - val_auc:  0.7433
# Epoch 22/30
# 12s - loss:  0.1224 - binary_crossentropy:  0.1224 - auc:  0.7916 - val_binary_crossentropy:  0.1293 - val_auc:  0.7418
# Epoch 23/30
# 12s - loss:  0.1218 - binary_crossentropy:  0.1218 - auc:  0.7958 - val_binary_crossentropy:  0.1287 - val_auc:  0.7410
# Epoch 24/30
# 12s - loss:  0.1212 - binary_crossentropy:  0.1212 - auc:  0.7997 - val_binary_crossentropy:  0.1292 - val_auc:  0.7378
# Epoch 25/30
# 12s - loss:  0.1221 - binary_crossentropy:  0.1210 - auc:  0.8037 - val_binary_crossentropy:  0.1304 - val_auc:  0.7407
# Epoch 26/30
# 12s - loss:  0.1197 - binary_crossentropy:  0.1196 - auc:  0.8092 - val_binary_crossentropy:  0.1295 - val_auc:  0.7423
# Epoch 27/30
# 12s - loss:  0.1191 - binary_crossentropy:  0.1191 - auc:  0.8112 - val_binary_crossentropy:  0.1300 - val_auc:  0.7418
# Epoch 28/30
# 12s - loss:  0.1183 - binary_crossentropy:  0.1183 - auc:  0.8154 - val_binary_crossentropy:  0.1305 - val_auc:  0.7409
# Epoch 29/30
# 12s - loss:  0.1176 - binary_crossentropy:  0.1176 - auc:  0.8197 - val_binary_crossentropy:  0.1301 - val_auc:  0.7390
# Epoch 30/30
# 12s - loss:  0.1170 - binary_crossentropy:  0.1171 - auc:  0.8221 - val_binary_crossentropy:  0.1311 - val_auc:  0.7380
#
# test LogLoss 0.134
# test AUC 0.7367
# test RIG 0.0535

# %% [markdown]
# ## PReLU

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='swish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
hist = model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=30, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/30
# 12s - loss:  0.1513 - binary_crossentropy:  0.1502 - auc:  0.6731 - val_binary_crossentropy:  0.1326 - val_auc:  0.6863
# Epoch 2/30
# 12s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6987 - val_binary_crossentropy:  0.1319 - val_auc:  0.6972
# Epoch 3/30
# 12s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7087 - val_binary_crossentropy:  0.1311 - val_auc:  0.7067
# Epoch 4/30
# 12s - loss:  0.1333 - binary_crossentropy:  0.1333 - auc:  0.7136 - val_binary_crossentropy:  0.1305 - val_auc:  0.7095
# Epoch 5/30
# 12s - loss:  0.1324 - binary_crossentropy:  0.1323 - auc:  0.7217 - val_binary_crossentropy:  0.1300 - val_auc:  0.7188
# Epoch 6/30
# 12s - loss:  0.1318 - binary_crossentropy:  0.1318 - auc:  0.7277 - val_binary_crossentropy:  0.1296 - val_auc:  0.7221
# Epoch 7/30
# 12s - loss:  0.1312 - binary_crossentropy:  0.1311 - auc:  0.7321 - val_binary_crossentropy:  0.1306 - val_auc:  0.7176
# Epoch 8/30
# 12s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7366 - val_binary_crossentropy:  0.1289 - val_auc:  0.7272
# Epoch 9/30
# 12s - loss:  0.1302 - binary_crossentropy:  0.1301 - auc:  0.7399 - val_binary_crossentropy:  0.1294 - val_auc:  0.7295
# Epoch 10/30
# 12s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7442 - val_binary_crossentropy:  0.1283 - val_auc:  0.7325
# Epoch 11/30
# 12s - loss:  0.1291 - binary_crossentropy:  0.1291 - auc:  0.7479 - val_binary_crossentropy:  0.1288 - val_auc:  0.7322
# Epoch 12/30
# 12s - loss:  0.1286 - binary_crossentropy:  0.1287 - auc:  0.7524 - val_binary_crossentropy:  0.1284 - val_auc:  0.7356
# Epoch 13/30
# 12s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7558 - val_binary_crossentropy:  0.1285 - val_auc:  0.7323
# Epoch 14/30
# 12s - loss:  0.1276 - binary_crossentropy:  0.1277 - auc:  0.7600 - val_binary_crossentropy:  0.1290 - val_auc:  0.7339
# Epoch 15/30
# 12s - loss:  0.1271 - binary_crossentropy:  0.1270 - auc:  0.7635 - val_binary_crossentropy:  0.1284 - val_auc:  0.7387
# Epoch 16/30
# 12s - loss:  0.1272 - binary_crossentropy:  0.1267 - auc:  0.7669 - val_binary_crossentropy:  0.1282 - val_auc:  0.7349
# Epoch 17/30
# 12s - loss:  0.1259 - binary_crossentropy:  0.1259 - auc:  0.7710 - val_binary_crossentropy:  0.1280 - val_auc:  0.7389
# Epoch 18/30
# 12s - loss:  0.1262 - binary_crossentropy:  0.1257 - auc:  0.7743 - val_binary_crossentropy:  0.1285 - val_auc:  0.7390
# Epoch 19/30
# 12s - loss:  0.1249 - binary_crossentropy:  0.1249 - auc:  0.7774 - val_binary_crossentropy:  0.1290 - val_auc:  0.7384
# Epoch 20/30
# 12s - loss:  0.1242 - binary_crossentropy:  0.1243 - auc:  0.7820 - val_binary_crossentropy:  0.1284 - val_auc:  0.7388
# Epoch 21/30
# 12s - loss:  0.1235 - binary_crossentropy:  0.1235 - auc:  0.7851 - val_binary_crossentropy:  0.1279 - val_auc:  0.7431
# Epoch 22/30
# 12s - loss:  0.1227 - binary_crossentropy:  0.1227 - auc:  0.7901 - val_binary_crossentropy:  0.1301 - val_auc:  0.7409
# Epoch 23/30
# 12s - loss:  0.1223 - binary_crossentropy:  0.1223 - auc:  0.7937 - val_binary_crossentropy:  0.1284 - val_auc:  0.7438
# Epoch 24/30
# 12s - loss:  0.1214 - binary_crossentropy:  0.1214 - auc:  0.7986 - val_binary_crossentropy:  0.1294 - val_auc:  0.7392
# Epoch 25/30
# 12s - loss:  0.1208 - binary_crossentropy:  0.1208 - auc:  0.8017 - val_binary_crossentropy:  0.1310 - val_auc:  0.7396
# Epoch 26/30
# 12s - loss:  0.1200 - binary_crossentropy:  0.1200 - auc:  0.8061 - val_binary_crossentropy:  0.1293 - val_auc:  0.7412
# Epoch 27/30
# 12s - loss:  0.1194 - binary_crossentropy:  0.1194 - auc:  0.8094 - val_binary_crossentropy:  0.1302 - val_auc:  0.7407
# Epoch 28/30
# 12s - loss:  0.1187 - binary_crossentropy:  0.1187 - auc:  0.8132 - val_binary_crossentropy:  0.1315 - val_auc:  0.7405
# Epoch 29/30
# 12s - loss:  0.1180 - binary_crossentropy:  0.1180 - auc:  0.8179 - val_binary_crossentropy:  0.1305 - val_auc:  0.7393
# Epoch 30/30
# 12s - loss:  0.1174 - binary_crossentropy:  0.1174 - auc:  0.8210 - val_binary_crossentropy:  0.1328 - val_auc:  0.7341
#
# test LogLoss 0.1355
# test AUC 0.7322
# test RIG 0.0424

# %%
from deepctr_torch.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_binary_crossentropy', min_delta=0, verbose=1, patience=5, mode='auto')

hist = model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2, callbacks=[es])

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(256, 256), dnn_dropout=0.0,
               dnn_activation='mish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )

# 모델 학습
# mdckpt = ModelCheckpoint(filepath='김동영/model.ckpt', monitor='val_binary_crossentropy', verbose=1, save_best_only=True, mode='min')

es = EarlyStopping(monitor='val_binary_crossentropy', min_delta=0, verbose=1, patience=5, mode='auto')
hist = model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2, callbacks=[es])

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 14s - loss:  0.1561 - binary_crossentropy:  0.1534 - auc:  0.6718 - val_binary_crossentropy:  0.1325 - val_auc:  0.6917
# Epoch 2/50
# 13s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6974 - val_binary_crossentropy:  0.1324 - val_auc:  0.6935
# Epoch 3/50
# 12s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7078 - val_binary_crossentropy:  0.1308 - val_auc:  0.7093
# Epoch 4/50
# 12s - loss:  0.1330 - binary_crossentropy:  0.1330 - auc:  0.7168 - val_binary_crossentropy:  0.1307 - val_auc:  0.7122
# Epoch 5/50
# 12s - loss:  0.1326 - binary_crossentropy:  0.1326 - auc:  0.7203 - val_binary_crossentropy:  0.1300 - val_auc:  0.7193
# Epoch 6/50
# 12s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7259 - val_binary_crossentropy:  0.1306 - val_auc:  0.7181
# Epoch 7/50
# 12s - loss:  0.1313 - binary_crossentropy:  0.1313 - auc:  0.7308 - val_binary_crossentropy:  0.1295 - val_auc:  0.7252
# Epoch 8/50
# 12s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7356 - val_binary_crossentropy:  0.1291 - val_auc:  0.7232
# Epoch 9/50
# 12s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7401 - val_binary_crossentropy:  0.1289 - val_auc:  0.7293
# Epoch 10/50
# 12s - loss:  0.1298 - binary_crossentropy:  0.1298 - auc:  0.7432 - val_binary_crossentropy:  0.1288 - val_auc:  0.7296
# Epoch 11/50
# 12s - loss:  0.1294 - binary_crossentropy:  0.1294 - auc:  0.7461 - val_binary_crossentropy:  0.1287 - val_auc:  0.7329
# Epoch 12/50
# 12s - loss:  0.1288 - binary_crossentropy:  0.1288 - auc:  0.7503 - val_binary_crossentropy:  0.1285 - val_auc:  0.7305
# Epoch 13/50
# 12s - loss:  0.1283 - binary_crossentropy:  0.1283 - auc:  0.7531 - val_binary_crossentropy:  0.1289 - val_auc:  0.7344
# Epoch 14/50
# 12s - loss:  0.1281 - binary_crossentropy:  0.1279 - auc:  0.7572 - val_binary_crossentropy:  0.1287 - val_auc:  0.7336
# Epoch 15/50
# 12s - loss:  0.1273 - binary_crossentropy:  0.1273 - auc:  0.7617 - val_binary_crossentropy:  0.1281 - val_auc:  0.7351
# Epoch 16/50
# 12s - loss:  0.1269 - binary_crossentropy:  0.1269 - auc:  0.7640 - val_binary_crossentropy:  0.1287 - val_auc:  0.7344
# Epoch 17/50
# 12s - loss:  0.1263 - binary_crossentropy:  0.1263 - auc:  0.7674 - val_binary_crossentropy:  0.1286 - val_auc:  0.7345
# Epoch 18/50
# 12s - loss:  0.1261 - binary_crossentropy:  0.1261 - auc:  0.7712 - val_binary_crossentropy:  0.1282 - val_auc:  0.7383
# Epoch 19/50
# 12s - loss:  0.1253 - binary_crossentropy:  0.1254 - auc:  0.7751 - val_binary_crossentropy:  0.1285 - val_auc:  0.7350
# Epoch 00019: early stopping
#
# test LogLoss 0.1311
# test AUC 0.734
# test RIG 0.0741

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(256, 256), dnn_dropout=0.0,
               dnn_activation='swish', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


es = EarlyStopping(monitor='val_auc', min_delta=0, verbose=1, patience=5, mode='min')
# mdckpt = ModelCheckpoint(filepath='김동영/model.ckpt', monitor='val_binary_crossentropy', verbose=1, save_best_only=True, mode='min')

# 모델 학습
hist = model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2, callbacks=[es])

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 13s - loss:  0.1580 - binary_crossentropy:  0.1550 - auc:  0.6683 - val_binary_crossentropy:  0.1326 - val_auc:  0.6874
# Epoch 2/50
# 12s - loss:  0.1349 - binary_crossentropy:  0.1349 - auc:  0.6963 - val_binary_crossentropy:  0.1322 - val_auc:  0.6953
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-c208fc54f37d> in <module>()
#      24
#      25 # 모델 학습
# ---> 26 hist = model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2, callbacks=[es])
#      27
#      28 # 평가
#
# /gdrive/.shortcut-targets-by-id/15_BxZVEQYCdGCGiQ5nexpWPc1cgHVe4w/3조/deepctr_torch/models/basemodel.py in fit(self, x, y, batch_size, epochs, verbose, initial_epoch, validation_split, validation_data, shuffle, callbacks)
#     238             try:
#     239                 with tqdm(enumerate(train_loader), disable=verbose != 1) as t:
# --> 240                     for _, (x_train, y_train) in t:
#     241                         x = x_train.to(self.device).float()
#     242                         y = y_train.to(self.device).float()
#
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py in __iter__(self)
#    1166         # (note: keep this check outside the loop for performance)
#    1167         if self.disable:
# -> 1168             for obj in iterable:
#    1169                 yield obj
#    1170             return
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
# ---> 52         return self.collate_fn(data)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      82             raise RuntimeError('each element in list of batch should be of equal size')
#      83         transposed = zip(*batch)
# ---> 84         return [default_collate(samples) for samples in transposed]
#      85
#      86     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/collate.py in <listcomp>(.0)
#      82             raise RuntimeError('each element in list of batch should be of equal size')
#      83         transposed = zip(*batch)
# ---> 84         return [default_collate(samples) for samples in transposed]
#      85
#      86     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      54             storage = elem.storage()._new_shared(numel)
#      55             out = elem.new(storage)
# ---> 56         return torch.stack(batch, 0, out=out)
#      57     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#      58             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %%
hist.model
# Out:
# DeepFM(
#   (embedding_dict): ModuleDict(
#     (viewer_gender): Embedding(3, 4)
#     (content_used): Embedding(2, 4)
#     (content_cat_1): Embedding(21, 4)
#     (content_cat_2): Embedding(94, 4)
#     (content_cat_3): Embedding(186, 4)
#     (content_status): Embedding(3, 4)
#     (content_delivery_fee): Embedding(3, 4)
#     (content_b_pay): Embedding(2, 4)
#     (content_place): Embedding(11, 4)
#   )
#   (linear_model): Linear(
#     (embedding_dict): ModuleDict(
#       (viewer_gender): Embedding(3, 1)
#       (content_used): Embedding(2, 1)
#       (content_cat_1): Embedding(21, 1)
#       (content_cat_2): Embedding(94, 1)
#       (content_cat_3): Embedding(186, 1)
#       (content_status): Embedding(3, 1)
#       (content_delivery_fee): Embedding(3, 1)
#       (content_b_pay): Embedding(2, 1)
#       (content_place): Embedding(11, 1)
#     )
#   )
#   (out): PredictionLayer()
#   (fm): FM()
#   (dnn): DNN(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (linears): ModuleList(
#       (0): Linear(in_features=56, out_features=512, bias=True)
#       (1): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (bn): ModuleList(
#       (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (activation_layers): ModuleList(
#       (0): SiLU()
#       (1): SiLU()
#     )
#   )
#   (dnn_linear): Linear(in_features=256, out_features=1, bias=False)
# )

# %% [markdown]
# # 1227

# %% [markdown]
# - 이미지 + onehot 전부

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 179s - loss:  0.1366 - binary_crossentropy:  0.1366 - auc:  0.6902 - val_binary_crossentropy:  0.1336 - val_auc:  0.7115
# Epoch 2/20
# 177s - loss:  0.1336 - binary_crossentropy:  0.1336 - auc:  0.7072 - val_binary_crossentropy:  0.1337 - val_auc:  0.7135
# Epoch 3/20
# 175s - loss:  0.1325 - binary_crossentropy:  0.1325 - auc:  0.7162 - val_binary_crossentropy:  0.1372 - val_auc:  0.7103
# Epoch 4/20
# 176s - loss:  0.1322 - binary_crossentropy:  0.1322 - auc:  0.7212 - val_binary_crossentropy:  0.1335 - val_auc:  0.7225
# Epoch 5/20
# 175s - loss:  0.1320 - binary_crossentropy:  0.1320 - auc:  0.7230 - val_binary_crossentropy:  0.1349 - val_auc:  0.7209
# Epoch 6/20
# 177s - loss:  0.1317 - binary_crossentropy:  0.1317 - auc:  0.7279 - val_binary_crossentropy:  0.1339 - val_auc:  0.7126
# Epoch 7/20
# 175s - loss:  0.1310 - binary_crossentropy:  0.1310 - auc:  0.7331 - val_binary_crossentropy:  0.1355 - val_auc:  0.7232
# Epoch 8/20
# 175s - loss:  0.1305 - binary_crossentropy:  0.1306 - auc:  0.7382 - val_binary_crossentropy:  0.1374 - val_auc:  0.7270
# Epoch 9/20
# 175s - loss:  0.1299 - binary_crossentropy:  0.1299 - auc:  0.7415 - val_binary_crossentropy:  0.1316 - val_auc:  0.7298
# Epoch 10/20
# 175s - loss:  0.1295 - binary_crossentropy:  0.1295 - auc:  0.7459 - val_binary_crossentropy:  0.1330 - val_auc:  0.7253
# Epoch 11/20
# 175s - loss:  0.1292 - binary_crossentropy:  0.1292 - auc:  0.7475 - val_binary_crossentropy:  0.1311 - val_auc:  0.7350
# Epoch 12/20
# 175s - loss:  0.1285 - binary_crossentropy:  0.1285 - auc:  0.7530 - val_binary_crossentropy:  0.1345 - val_auc:  0.7362
# Epoch 13/20
# 175s - loss:  0.1284 - binary_crossentropy:  0.1284 - auc:  0.7549 - val_binary_crossentropy:  0.1334 - val_auc:  0.7295
# Epoch 14/20
# 175s - loss:  0.1283 - binary_crossentropy:  0.1283 - auc:  0.7564 - val_binary_crossentropy:  0.1333 - val_auc:  0.7352
# Epoch 15/20
# 176s - loss:  0.1276 - binary_crossentropy:  0.1276 - auc:  0.7604 - val_binary_crossentropy:  0.1312 - val_auc:  0.7428
# Epoch 16/20
# 176s - loss:  0.1273 - binary_crossentropy:  0.1273 - auc:  0.7605 - val_binary_crossentropy:  0.1328 - val_auc:  0.7290
# Epoch 17/20
# 175s - loss:  0.1272 - binary_crossentropy:  0.1271 - auc:  0.7612 - val_binary_crossentropy:  0.1359 - val_auc:  0.7225
# Epoch 18/20
# 176s - loss:  0.1275 - binary_crossentropy:  0.1275 - auc:  0.7634 - val_binary_crossentropy:  0.1308 - val_auc:  0.7430
# Epoch 19/20
# 175s - loss:  0.1274 - binary_crossentropy:  0.1273 - auc:  0.7645 - val_binary_crossentropy:  0.1317 - val_auc:  0.7370
# Epoch 20/20
# 175s - loss:  0.1266 - binary_crossentropy:  0.1266 - auc:  0.7655 - val_binary_crossentropy:  0.1341 - val_auc:  0.7444
#
# test LogLoss 0.1357
# test AUC 0.7303
# test RIG 0.0404

# %% [markdown]
# ## 다 포함

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256, 128), dnn_dropout=0.1,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 27s - loss:  0.1407 - binary_crossentropy:  0.1407 - auc:  0.6689 - val_binary_crossentropy:  0.1321 - val_auc:  0.6931
# Epoch 2/20
# 27s - loss:  0.1349 - binary_crossentropy:  0.1349 - auc:  0.6986 - val_binary_crossentropy:  0.1310 - val_auc:  0.7062
# Epoch 3/20
# 27s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7131 - val_binary_crossentropy:  0.1309 - val_auc:  0.7114
# Epoch 4/20
# 26s - loss:  0.1328 - binary_crossentropy:  0.1328 - auc:  0.7192 - val_binary_crossentropy:  0.1301 - val_auc:  0.7155
# Epoch 5/20
# 27s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7265 - val_binary_crossentropy:  0.1302 - val_auc:  0.7165
# Epoch 6/20
# 26s - loss:  0.1312 - binary_crossentropy:  0.1313 - auc:  0.7307 - val_binary_crossentropy:  0.1295 - val_auc:  0.7226
# Epoch 7/20
# 26s - loss:  0.1308 - binary_crossentropy:  0.1308 - auc:  0.7347 - val_binary_crossentropy:  0.1289 - val_auc:  0.7247
# Epoch 8/20
# 26s - loss:  0.1301 - binary_crossentropy:  0.1301 - auc:  0.7402 - val_binary_crossentropy:  0.1291 - val_auc:  0.7255
# Epoch 9/20
# 26s - loss:  0.1295 - binary_crossentropy:  0.1295 - auc:  0.7443 - val_binary_crossentropy:  0.1299 - val_auc:  0.7242
# Epoch 10/20
# 26s - loss:  0.1289 - binary_crossentropy:  0.1289 - auc:  0.7475 - val_binary_crossentropy:  0.1285 - val_auc:  0.7299
# Epoch 11/20
# 26s - loss:  0.1283 - binary_crossentropy:  0.1283 - auc:  0.7529 - val_binary_crossentropy:  0.1291 - val_auc:  0.7263
# Epoch 12/20
# 26s - loss:  0.1279 - binary_crossentropy:  0.1278 - auc:  0.7567 - val_binary_crossentropy:  0.1289 - val_auc:  0.7293
# Epoch 13/20
# 26s - loss:  0.1271 - binary_crossentropy:  0.1271 - auc:  0.7609 - val_binary_crossentropy:  0.1289 - val_auc:  0.7322
# Epoch 14/20
# 26s - loss:  0.1266 - binary_crossentropy:  0.1266 - auc:  0.7659 - val_binary_crossentropy:  0.1282 - val_auc:  0.7336
# Epoch 15/20
# 26s - loss:  0.1261 - binary_crossentropy:  0.1261 - auc:  0.7677 - val_binary_crossentropy:  0.1288 - val_auc:  0.7303
# Epoch 16/20
# 26s - loss:  0.1255 - binary_crossentropy:  0.1255 - auc:  0.7722 - val_binary_crossentropy:  0.1296 - val_auc:  0.7293
# Epoch 17/20
# 26s - loss:  0.1249 - binary_crossentropy:  0.1249 - auc:  0.7757 - val_binary_crossentropy:  0.1286 - val_auc:  0.7319
# Epoch 18/20
# 26s - loss:  0.1244 - binary_crossentropy:  0.1244 - auc:  0.7803 - val_binary_crossentropy:  0.1293 - val_auc:  0.7331
# Epoch 19/20
# 26s - loss:  0.1237 - binary_crossentropy:  0.1237 - auc:  0.7846 - val_binary_crossentropy:  0.1305 - val_auc:  0.7342
# Epoch 20/20
# 26s - loss:  0.1232 - binary_crossentropy:  0.1232 - auc:  0.7884 - val_binary_crossentropy:  0.1287 - val_auc:  0.7336
#
# test LogLoss 0.1312
# test AUC 0.7357
# test RIG 0.0731

# %% [markdown]
# test LogLoss 0.1318
# test AUC 0.7343
# test RIG 0.0689

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(256, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.0)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 588555 samples, validate on 0 samples, 1150 steps per epoch
# Epoch 1/50
# 20s - loss:  0.1366 - binary_crossentropy:  0.1366 - auc:  0.6928
# Epoch 2/50
# 20s - loss:  0.1335 - binary_crossentropy:  0.1335 - auc:  0.7089
# Epoch 3/50
# 20s - loss:  0.1330 - binary_crossentropy:  0.1330 - auc:  0.7153
# Epoch 4/50
# 20s - loss:  0.1328 - binary_crossentropy:  0.1328 - auc:  0.7183
# Epoch 5/50
# 20s - loss:  0.1325 - binary_crossentropy:  0.1325 - auc:  0.7197
# Epoch 6/50
# 20s - loss:  0.1322 - binary_crossentropy:  0.1322 - auc:  0.7224
# Epoch 7/50
# 20s - loss:  0.1321 - binary_crossentropy:  0.1321 - auc:  0.7254
# Epoch 8/50
# 20s - loss:  0.1317 - binary_crossentropy:  0.1317 - auc:  0.7282
# Epoch 9/50
# 20s - loss:  0.1316 - binary_crossentropy:  0.1315 - auc:  0.7284
# Epoch 10/50
# 20s - loss:  0.1314 - binary_crossentropy:  0.1314 - auc:  0.7311
# Epoch 11/50
# 20s - loss:  0.1312 - binary_crossentropy:  0.1312 - auc:  0.7334
# Epoch 12/50
# 20s - loss:  0.1310 - binary_crossentropy:  0.1310 - auc:  0.7343
# Epoch 13/50
# 20s - loss:  0.1309 - binary_crossentropy:  0.1309 - auc:  0.7375
# Epoch 14/50
# 20s - loss:  0.1306 - binary_crossentropy:  0.1305 - auc:  0.7387
# Epoch 15/50
# 20s - loss:  0.1306 - binary_crossentropy:  0.1306 - auc:  0.7402
# Epoch 16/50
# 20s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7424
# Epoch 17/50
# 20s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7442
# Epoch 18/50
# 20s - loss:  0.1297 - binary_crossentropy:  0.1297 - auc:  0.7447
# Epoch 19/50
# 20s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7468
# Epoch 20/50
# 20s - loss:  0.1294 - binary_crossentropy:  0.1294 - auc:  0.7495
# Epoch 21/50
# 20s - loss:  0.1293 - binary_crossentropy:  0.1293 - auc:  0.7511
# Epoch 22/50
# 20s - loss:  0.1291 - binary_crossentropy:  0.1291 - auc:  0.7530
# Epoch 23/50
# 20s - loss:  0.1288 - binary_crossentropy:  0.1288 - auc:  0.7544
# Epoch 24/50
# 20s - loss:  0.1286 - binary_crossentropy:  0.1287 - auc:  0.7564
# Epoch 25/50
# 20s - loss:  0.1284 - binary_crossentropy:  0.1284 - auc:  0.7575
# Epoch 26/50
# 20s - loss:  0.1282 - binary_crossentropy:  0.1282 - auc:  0.7590
# Epoch 27/50
# 20s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7607
# Epoch 28/50
# 20s - loss:  0.1279 - binary_crossentropy:  0.1279 - auc:  0.7616
# Epoch 29/50
# 20s - loss:  0.1275 - binary_crossentropy:  0.1275 - auc:  0.7634
# Epoch 30/50
# 20s - loss:  0.1275 - binary_crossentropy:  0.1275 - auc:  0.7653
# Epoch 31/50
# 20s - loss:  0.1272 - binary_crossentropy:  0.1272 - auc:  0.7667
# Epoch 32/50
# 20s - loss:  0.1270 - binary_crossentropy:  0.1270 - auc:  0.7673
# Epoch 33/50
# 20s - loss:  0.1268 - binary_crossentropy:  0.1268 - auc:  0.7702
# Epoch 34/50
# 20s - loss:  0.1267 - binary_crossentropy:  0.1267 - auc:  0.7699
# Epoch 35/50
# 20s - loss:  0.1265 - binary_crossentropy:  0.1265 - auc:  0.7722
# Epoch 36/50
# 20s - loss:  0.1264 - binary_crossentropy:  0.1264 - auc:  0.7733
# Epoch 37/50
# 20s - loss:  0.1262 - binary_crossentropy:  0.1261 - auc:  0.7741
# Epoch 38/50
# 20s - loss:  0.1260 - binary_crossentropy:  0.1260 - auc:  0.7753
# Epoch 39/50
# 20s - loss:  0.1258 - binary_crossentropy:  0.1258 - auc:  0.7775
# Epoch 40/50
# 20s - loss:  0.1256 - binary_crossentropy:  0.1256 - auc:  0.7780
# Epoch 41/50
# 20s - loss:  0.1254 - binary_crossentropy:  0.1254 - auc:  0.7794
# Epoch 42/50
# 20s - loss:  0.1254 - binary_crossentropy:  0.1254 - auc:  0.7807
# Epoch 43/50
# 20s - loss:  0.1251 - binary_crossentropy:  0.1251 - auc:  0.7821
# Epoch 44/50
# 20s - loss:  0.1251 - binary_crossentropy:  0.1251 - auc:  0.7820
# Epoch 45/50
# 20s - loss:  0.1247 - binary_crossentropy:  0.1247 - auc:  0.7835
# Epoch 46/50
# 20s - loss:  0.1247 - binary_crossentropy:  0.1247 - auc:  0.7846
# Epoch 47/50
# 20s - loss:  0.1247 - binary_crossentropy:  0.1247 - auc:  0.7845
# Epoch 48/50
# 20s - loss:  0.1245 - binary_crossentropy:  0.1246 - auc:  0.7863
# Epoch 49/50
# 20s - loss:  0.1243 - binary_crossentropy:  0.1242 - auc:  0.7863
# Epoch 50/50
# 20s - loss:  0.1242 - binary_crossentropy:  0.1242 - auc:  0.7885
#
# test LogLoss 0.136
# test AUC 0.7206
# test RIG 0.0408

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 21s - loss:  0.1443 - binary_crossentropy:  0.1443 - auc:  0.6785 - val_binary_crossentropy:  0.1313 - val_auc:  0.6998
# Epoch 2/20
# 21s - loss:  0.1348 - binary_crossentropy:  0.1347 - auc:  0.7011 - val_binary_crossentropy:  0.1301 - val_auc:  0.7132
# Epoch 3/20
# 21s - loss:  0.1340 - binary_crossentropy:  0.1340 - auc:  0.7096 - val_binary_crossentropy:  0.1313 - val_auc:  0.7112
# Epoch 4/20
# 21s - loss:  0.1336 - binary_crossentropy:  0.1336 - auc:  0.7122 - val_binary_crossentropy:  0.1313 - val_auc:  0.7041
# Epoch 5/20
# 21s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7127 - val_binary_crossentropy:  0.1306 - val_auc:  0.7077
# Epoch 6/20
# 21s - loss:  0.1331 - binary_crossentropy:  0.1331 - auc:  0.7173 - val_binary_crossentropy:  0.1320 - val_auc:  0.7037
# Epoch 7/20
# 21s - loss:  0.1330 - binary_crossentropy:  0.1330 - auc:  0.7185 - val_binary_crossentropy:  0.1307 - val_auc:  0.7105
# Epoch 8/20
# 20s - loss:  0.1329 - binary_crossentropy:  0.1329 - auc:  0.7191 - val_binary_crossentropy:  0.1312 - val_auc:  0.7041
# Epoch 9/20
# 20s - loss:  0.1326 - binary_crossentropy:  0.1326 - auc:  0.7226 - val_binary_crossentropy:  0.1307 - val_auc:  0.7147
# Epoch 10/20
# 20s - loss:  0.1324 - binary_crossentropy:  0.1324 - auc:  0.7242 - val_binary_crossentropy:  0.1305 - val_auc:  0.7133
# Epoch 11/20
# 20s - loss:  0.1321 - binary_crossentropy:  0.1321 - auc:  0.7251 - val_binary_crossentropy:  0.1304 - val_auc:  0.7124
# Epoch 12/20
# 20s - loss:  0.1319 - binary_crossentropy:  0.1319 - auc:  0.7270 - val_binary_crossentropy:  0.1306 - val_auc:  0.7157
# Epoch 13/20
# 20s - loss:  0.1318 - binary_crossentropy:  0.1318 - auc:  0.7295 - val_binary_crossentropy:  0.1308 - val_auc:  0.7117
# Epoch 14/20
# 20s - loss:  0.1316 - binary_crossentropy:  0.1316 - auc:  0.7296 - val_binary_crossentropy:  0.1306 - val_auc:  0.7139
# Epoch 15/20
# 21s - loss:  0.1315 - binary_crossentropy:  0.1315 - auc:  0.7307 - val_binary_crossentropy:  0.1303 - val_auc:  0.7161
# Epoch 16/20
# 20s - loss:  0.1312 - binary_crossentropy:  0.1312 - auc:  0.7343 - val_binary_crossentropy:  0.1310 - val_auc:  0.7124
# Epoch 17/20
# 20s - loss:  0.1311 - binary_crossentropy:  0.1310 - auc:  0.7343 - val_binary_crossentropy:  0.1307 - val_auc:  0.7169
# Epoch 18/20
# 20s - loss:  0.1309 - binary_crossentropy:  0.1309 - auc:  0.7370 - val_binary_crossentropy:  0.1312 - val_auc:  0.7161
# Epoch 19/20
# 20s - loss:  0.1308 - binary_crossentropy:  0.1307 - auc:  0.7386 - val_binary_crossentropy:  0.1304 - val_auc:  0.7171
# Epoch 20/20
# 20s - loss:  0.1305 - binary_crossentropy:  0.1305 - auc:  0.7400 - val_binary_crossentropy:  0.1309 - val_auc:  0.7148
#
# test LogLoss 0.1324
# test AUC 0.716
# test RIG 0.0662

# %%
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
# model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
#                 task='binary',
#                 l2_reg_embedding=1e-5, device=device)

model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256, 128), dnn_dropout=0.0,
               dnn_activation='relu', dnn_use_bn=True, task='binary', device=device, gpus=[0])


# optimizer, loss 설정
model.compile("adam", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )


# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=20, verbose=2, validation_split=0.2)

# 평가
pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# parallel running on these gpus: [0]
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/20
# 21s - loss:  0.1417 - binary_crossentropy:  0.1417 - auc:  0.6719 - val_binary_crossentropy:  0.1321 - val_auc:  0.6953
# Epoch 2/20
# 19s - loss:  0.1345 - binary_crossentropy:  0.1345 - auc:  0.7009 - val_binary_crossentropy:  0.1312 - val_auc:  0.7059
# Epoch 3/20
# 19s - loss:  0.1332 - binary_crossentropy:  0.1332 - auc:  0.7135 - val_binary_crossentropy:  0.1314 - val_auc:  0.7166
# Epoch 4/20
# 19s - loss:  0.1325 - binary_crossentropy:  0.1325 - auc:  0.7191 - val_binary_crossentropy:  0.1307 - val_auc:  0.7129
# Epoch 5/20
# 19s - loss:  0.1318 - binary_crossentropy:  0.1318 - auc:  0.7265 - val_binary_crossentropy:  0.1297 - val_auc:  0.7219
# Epoch 6/20
# 19s - loss:  0.1314 - binary_crossentropy:  0.1313 - auc:  0.7295 - val_binary_crossentropy:  0.1292 - val_auc:  0.7253
# Epoch 7/20
# 19s - loss:  0.1306 - binary_crossentropy:  0.1306 - auc:  0.7367 - val_binary_crossentropy:  0.1289 - val_auc:  0.7267
# Epoch 8/20
# 19s - loss:  0.1300 - binary_crossentropy:  0.1301 - auc:  0.7398 - val_binary_crossentropy:  0.1286 - val_auc:  0.7295
# Epoch 9/20
# 19s - loss:  0.1295 - binary_crossentropy:  0.1295 - auc:  0.7444 - val_binary_crossentropy:  0.1289 - val_auc:  0.7302
# Epoch 10/20
# 19s - loss:  0.1290 - binary_crossentropy:  0.1290 - auc:  0.7490 - val_binary_crossentropy:  0.1293 - val_auc:  0.7287
# Epoch 11/20
# 18s - loss:  0.1284 - binary_crossentropy:  0.1284 - auc:  0.7537 - val_binary_crossentropy:  0.1282 - val_auc:  0.7336
# Epoch 12/20
# 19s - loss:  0.1280 - binary_crossentropy:  0.1280 - auc:  0.7557 - val_binary_crossentropy:  0.1282 - val_auc:  0.7348
# Epoch 13/20
# 19s - loss:  0.1273 - binary_crossentropy:  0.1273 - auc:  0.7603 - val_binary_crossentropy:  0.1292 - val_auc:  0.7330
# Epoch 14/20
# 19s - loss:  0.1269 - binary_crossentropy:  0.1269 - auc:  0.7640 - val_binary_crossentropy:  0.1280 - val_auc:  0.7358
# Epoch 15/20
# 19s - loss:  0.1264 - binary_crossentropy:  0.1264 - auc:  0.7673 - val_binary_crossentropy:  0.1291 - val_auc:  0.7358
# Epoch 16/20
# 19s - loss:  0.1259 - binary_crossentropy:  0.1259 - auc:  0.7709 - val_binary_crossentropy:  0.1286 - val_auc:  0.7369
# Epoch 17/20
# 19s - loss:  0.1255 - binary_crossentropy:  0.1255 - auc:  0.7723 - val_binary_crossentropy:  0.1285 - val_auc:  0.7379
# Epoch 18/20
# 18s - loss:  0.1251 - binary_crossentropy:  0.1251 - auc:  0.7757 - val_binary_crossentropy:  0.1282 - val_auc:  0.7363
# Epoch 19/20
# 19s - loss:  0.1246 - binary_crossentropy:  0.1246 - auc:  0.7791 - val_binary_crossentropy:  0.1293 - val_auc:  0.7369
# Epoch 20/20
# 19s - loss:  0.1240 - binary_crossentropy:  0.1241 - auc:  0.7824 - val_binary_crossentropy:  0.1290 - val_auc:  0.7383
#
# test LogLoss 0.1321
# test AUC 0.7348
# test RIG 0.0667

# %% [markdown]
# # 학습 - 1223

# %% [markdown]
# - Standard Scaling, 이미지 벡터 제외

# %%
# 4.Define Model,train,predict and evaluate
# cpu gpu 설정
# device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

# 모델 정의
model = DeepFM(linear_feature_columns=linear_feature_columns, dnn_feature_columns=dnn_feature_columns,
                task='binary',
                l2_reg_embedding=1e-5, device=device)

# optimizer, loss 설정
model.compile("adagrad", "binary_crossentropy",
                metrics=["binary_crossentropy", "auc"], )
# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=1024, epochs=20, verbose=2, validation_split=0.0)

# 예측
pred_ans = model.predict(test_model_input, 1024)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda ready...
# cuda:0
# Train on 588555 samples, validate on 0 samples, 575 steps per epoch
# Epoch 1/20
# 8s - loss:  0.1388 - binary_crossentropy:  0.1388 - auc:  0.6745
# Epoch 2/20
# 8s - loss:  0.1350 - binary_crossentropy:  0.1350 - auc:  0.6879
# Epoch 3/20
# 8s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6896
# Epoch 4/20
# 8s - loss:  0.1346 - binary_crossentropy:  0.1346 - auc:  0.6899
# Epoch 5/20
# 8s - loss:  0.1346 - binary_crossentropy:  0.1346 - auc:  0.6918
# Epoch 6/20
# 8s - loss:  0.1345 - binary_crossentropy:  0.1344 - auc:  0.6924
# Epoch 7/20
# 8s - loss:  0.1344 - binary_crossentropy:  0.1344 - auc:  0.6931
# Epoch 8/20
# 8s - loss:  0.1343 - binary_crossentropy:  0.1343 - auc:  0.6942
# Epoch 9/20
# 8s - loss:  0.1342 - binary_crossentropy:  0.1342 - auc:  0.6941
# Epoch 10/20
# 8s - loss:  0.1342 - binary_crossentropy:  0.1342 - auc:  0.6956
# Epoch 11/20
# 8s - loss:  0.1341 - binary_crossentropy:  0.1341 - auc:  0.6955
# Epoch 12/20
# 8s - loss:  0.1341 - binary_crossentropy:  0.1341 - auc:  0.6963
# Epoch 13/20
# 8s - loss:  0.1340 - binary_crossentropy:  0.1340 - auc:  0.6962
# Epoch 14/20
# 8s - loss:  0.1340 - binary_crossentropy:  0.1340 - auc:  0.6977
# Epoch 15/20
# 8s - loss:  0.1340 - binary_crossentropy:  0.1340 - auc:  0.6977
# Epoch 16/20
# 8s - loss:  0.1339 - binary_crossentropy:  0.1339 - auc:  0.6983
# Epoch 17/20
# 8s - loss:  0.1339 - binary_crossentropy:  0.1339 - auc:  0.6984
# Epoch 18/20
# 8s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.6985
# Epoch 19/20
# 8s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.6991
# Epoch 20/20
# 8s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.6993
#
# test LogLoss 0.1331
# test AUC 0.6995
# test RIG 0.0616

# %% [markdown]
# - Standard Scaling, 이미지 벡터 전부 사용

# %%
# 모델 학습
model.fit(x = train_model_input, y = train[target].values, batch_size=1024, epochs=20, verbose=2, validation_split=0.0)

# 예측
pred_ans = model.predict(test_model_input, 1024)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans), 4))
# Out:
# cuda:0
# Train on 588555 samples, validate on 0 samples, 575 steps per epoch
# Epoch 1/20
# 11s - loss:  0.1303 - binary_crossentropy:  0.1303 - auc:  0.7360
# Epoch 2/20
# 11s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7356
# Epoch 3/20
# 11s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7365
# Epoch 4/20
# 11s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7366
# Epoch 5/20
# 11s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7366
# Epoch 6/20
# 11s - loss:  0.1301 - binary_crossentropy:  0.1301 - auc:  0.7376
# Epoch 7/20
# 11s - loss:  0.1301 - binary_crossentropy:  0.1301 - auc:  0.7374
# Epoch 8/20
# 11s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7381
# Epoch 9/20
# 11s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7387
# Epoch 10/20
# 11s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7386
# Epoch 11/20
# 11s - loss:  0.1299 - binary_crossentropy:  0.1299 - auc:  0.7391
# Epoch 12/20
# 11s - loss:  0.1299 - binary_crossentropy:  0.1299 - auc:  0.7392
# Epoch 13/20
# 11s - loss:  0.1299 - binary_crossentropy:  0.1299 - auc:  0.7392
# Epoch 14/20
# 11s - loss:  0.1298 - binary_crossentropy:  0.1298 - auc:  0.7402
# Epoch 15/20
# 11s - loss:  0.1298 - binary_crossentropy:  0.1298 - auc:  0.7399
# Epoch 16/20
# 11s - loss:  0.1298 - binary_crossentropy:  0.1298 - auc:  0.7404
# Epoch 17/20
# 12s - loss:  0.1297 - binary_crossentropy:  0.1297 - auc:  0.7407
# Epoch 18/20
# 11s - loss:  0.1297 - binary_crossentropy:  0.1297 - auc:  0.7409
# Epoch 19/20
# 11s - loss:  0.1297 - binary_crossentropy:  0.1297 - auc:  0.7408
# Epoch 20/20
# 11s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7415
#
# test LogLoss 0.1304
# test AUC 0.7279
# test RIG 0.0805
