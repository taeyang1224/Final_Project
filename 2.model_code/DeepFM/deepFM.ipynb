# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd '../gdrive/MyDrive/SSAC/3조'
# Out:
# /gdrive/.shortcut-targets-by-id/15_BxZVEQYCdGCGiQ5nexpWPc1cgHVe4w/3조

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler, StandardScaler, RobustScaler
from deepctr_torch.inputs import SparseFeat, DenseFeat, get_feature_names
from deepctr_torch.models import *
from deepctr_torch.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_csv('data/total_data.csv')

# %% [markdown]
# # 평가함수 정의

# %%
from sklearn.metrics import log_loss, roc_auc_score

grouped_label = df.groupby('label').size()
avg_ctr = float(grouped_label[1]/grouped_label.sum())

def get_rig(train_y, test_y, pred, avg_ctr):
    prior = log_loss(train_y, [avg_ctr]*len(train_y))

    classifier = log_loss(test_y, pred)

    rig = (prior - classifier) / prior
    return rig

# %%
categorical = [
    'viewer_gender',  
    'content_used',
    'content_cat_1',
    #'content_cat_2',
    #'content_cat_3',
    "content_status",
    'content_delivery_fee',
    #'content_b_pay', 
    'content_place',
    ]

continuous = [
    'content_price',
    'adv_item_count',         
    'title_len',
    'bid_price', 
    'content_emergency_count',
    'content_comment_count',     
    'content_views',       
    #'content_likes',
    'adv_follower_count',
    #'adv_grade',       
    'adv_views',
    'adv_review_count',
    'adv_comment_count',
    'adv_pay_count',
    'adv_parcel_post_count', 
    'adv_transfer_count', 
    #'adv_chat_count',
    'viewer_age',
    'viewer_following_count',
    'viewer_pay_count',
    "viewer_parcel_post_count",
    'viewer_transfer_count',
    'viewer_chat_count'
    ]

# %% [markdown]
# # 전처리 함수 정의

# %%
def encoder(df, col, enc):
    df_ = df.copy()

    if enc == "label":
        col_ = col
        for feat in col:
            lbe = LabelEncoder()
            df_[feat] = lbe.fit_transform(df_[feat])

    elif enc == "onehot":
        num = len(df_.columns) - len(col)
        df_ = pd.get_dummies(df_, columns=col, drop_first=True)
        col_ = df_.columns[num:].tolist()

    return df_, col_

def scaler(df, col, name):
    df_ = df.copy()

    if name == "minmax":
       scaler = MinMaxScaler(feature_range=(0, 1))

    elif name == "standard":
       scaler = StandardScaler()
    elif name == "robust":
       scaler = RobustScaler()
    
    df_[col] = scaler.fit_transform(df_[col])
    
    return df_

# 결측치 채우기

def prepare_training(df, categorical, continuous, enc = "label", scale = "standard"):
    df[categorical] = df[categorical].fillna('-1', )
    df[continuous] = df[continuous].fillna(0, )
    df, categorical = encoder(df, categorical, enc=enc)
    df = scaler(df, continuous, name=scale)

    train, test = train_test_split(df, test_size=0.2, random_state=47)#, stratify=df['label'])

    fixlen_feature_columns = [SparseFeat(feat, df[feat].nunique())
                            for feat in categorical] + [DenseFeat(feat, 1, )
                                                            for feat in continuous]

    # dnn feature에 일단 모든 feature 정보 넣기
    dnn_feature_columns = fixlen_feature_columns

    # lenear feature에도 일단 모든 feature 정보 넣기
    linear_feature_columns = fixlen_feature_columns 

    # feature 이름들만 따로 저장
    feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

    # train/test 데이터의 각 feature에 대응하는 컬럼을 딕셔너리로 저장
    train_model_input = {name: train[name] for name in feature_names}
    test_model_input = {name: test[name] for name in feature_names}

    return [train, test, linear_feature_columns, dnn_feature_columns, train_model_input, test_model_input]

# %% [markdown]
# # 학습 및 평가

# %%
[train, test, linear_feature_columns, dnn_feature_columns, train_model_input, test_model_input] = prepare_training(df, categorical, continuous)

target = ['label']
#device = 'cpu'
use_gpu = True
if use_gpu and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'

params = {"dnn_hidden_units" : (512, 256), "dnn_dropout" : 0.0, "dnn_activation" : 'relu', "dnn_use_bn" : False, "task" :'binary'}
model = DeepFM(linear_feature_columns, dnn_feature_columns, params, device=device)

# model = DeepFM(linear_feature_columns, dnn_feature_columns, dnn_hidden_units=(512, 256), dnn_dropout=0.0,
#            dnn_activation='relu', dnn_use_bn=False, task='binary', device=device)

# optimizer, loss 설정
model.compile("adam", "binary_crossentropy", metrics=["binary_crossentropy", "auc"], )


# 모델 학습
es = EarlyStopping(monitor='val_binary_crossentropy', min_delta=0, verbose=1, patience=5, mode='auto')
hist = model.fit(x = train_model_input, y = train[target].values, batch_size=512, epochs=50, verbose=2, validation_split=0.2, callbacks=[es])

pred_ans = model.predict(test_model_input, 512)
print("")
print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
print("test RIG", round(get_rig(train[target].values, test[target].values, pred_ans, avg_ctr), 4))
# Out:
# cuda ready...
# cuda:0
# Train on 470844 samples, validate on 117711 samples, 920 steps per epoch
# Epoch 1/50
# 10s - loss:  0.1491 - binary_crossentropy:  0.1491 - auc:  0.6549 - val_binary_crossentropy:  0.1346 - val_auc:  0.6662
# Epoch 2/50
# 10s - loss:  0.1362 - binary_crossentropy:  0.1362 - auc:  0.6749 - val_binary_crossentropy:  0.1332 - val_auc:  0.6751
# Epoch 3/50
# 9s - loss:  0.1358 - binary_crossentropy:  0.1358 - auc:  0.6814 - val_binary_crossentropy:  0.1335 - val_auc:  0.6783
# Epoch 4/50
# 10s - loss:  0.1353 - binary_crossentropy:  0.1353 - auc:  0.6875 - val_binary_crossentropy:  0.1331 - val_auc:  0.6894
# Epoch 5/50
# 10s - loss:  0.1348 - binary_crossentropy:  0.1348 - auc:  0.6934 - val_binary_crossentropy:  0.1320 - val_auc:  0.6924
# Epoch 6/50
# 9s - loss:  0.1345 - binary_crossentropy:  0.1345 - auc:  0.6978 - val_binary_crossentropy:  0.1318 - val_auc:  0.6944
# Epoch 7/50
# 9s - loss:  0.1343 - binary_crossentropy:  0.1343 - auc:  0.7004 - val_binary_crossentropy:  0.1319 - val_auc:  0.6957
# Epoch 8/50
# 10s - loss:  0.1341 - binary_crossentropy:  0.1340 - auc:  0.7024 - val_binary_crossentropy:  0.1315 - val_auc:  0.6976
# Epoch 9/50
# 10s - loss:  0.1338 - binary_crossentropy:  0.1338 - auc:  0.7040 - val_binary_crossentropy:  0.1320 - val_auc:  0.6951
# Epoch 10/50
# 10s - loss:  0.1336 - binary_crossentropy:  0.1336 - auc:  0.7070 - val_binary_crossentropy:  0.1316 - val_auc:  0.6984
# Epoch 11/50
# 10s - loss:  0.1334 - binary_crossentropy:  0.1334 - auc:  0.7092 - val_binary_crossentropy:  0.1314 - val_auc:  0.7030
# Epoch 12/50
# 9s - loss:  0.1331 - binary_crossentropy:  0.1331 - auc:  0.7132 - val_binary_crossentropy:  0.1309 - val_auc:  0.7049
# Epoch 13/50
# 9s - loss:  0.1327 - binary_crossentropy:  0.1328 - auc:  0.7155 - val_binary_crossentropy:  0.1309 - val_auc:  0.7057
# Epoch 14/50
# 9s - loss:  0.1326 - binary_crossentropy:  0.1326 - auc:  0.7168 - val_binary_crossentropy:  0.1307 - val_auc:  0.7095
# Epoch 15/50
# 10s - loss:  0.1323 - binary_crossentropy:  0.1323 - auc:  0.7202 - val_binary_crossentropy:  0.1305 - val_auc:  0.7116
# Epoch 16/50
# 9s - loss:  0.1320 - binary_crossentropy:  0.1320 - auc:  0.7226 - val_binary_crossentropy:  0.1303 - val_auc:  0.7110
# Epoch 17/50
# 9s - loss:  0.1318 - binary_crossentropy:  0.1318 - auc:  0.7260 - val_binary_crossentropy:  0.1301 - val_auc:  0.7145
# Epoch 18/50
# 10s - loss:  0.1316 - binary_crossentropy:  0.1316 - auc:  0.7298 - val_binary_crossentropy:  0.1309 - val_auc:  0.7149
# Epoch 19/50
# 9s - loss:  0.1314 - binary_crossentropy:  0.1314 - auc:  0.7291 - val_binary_crossentropy:  0.1301 - val_auc:  0.7166
# Epoch 20/50
# 9s - loss:  0.1311 - binary_crossentropy:  0.1311 - auc:  0.7318 - val_binary_crossentropy:  0.1299 - val_auc:  0.7175
# Epoch 21/50
# 9s - loss:  0.1310 - binary_crossentropy:  0.1310 - auc:  0.7331 - val_binary_crossentropy:  0.1303 - val_auc:  0.7192
# Epoch 22/50
# 9s - loss:  0.1307 - binary_crossentropy:  0.1307 - auc:  0.7356 - val_binary_crossentropy:  0.1294 - val_auc:  0.7216
# Epoch 23/50
# 9s - loss:  0.1305 - binary_crossentropy:  0.1305 - auc:  0.7370 - val_binary_crossentropy:  0.1296 - val_auc:  0.7203
# Epoch 24/50
# 9s - loss:  0.1304 - binary_crossentropy:  0.1304 - auc:  0.7384 - val_binary_crossentropy:  0.1293 - val_auc:  0.7228
# Epoch 25/50
# 10s - loss:  0.1302 - binary_crossentropy:  0.1302 - auc:  0.7395 - val_binary_crossentropy:  0.1291 - val_auc:  0.7233
# Epoch 26/50
# 9s - loss:  0.1300 - binary_crossentropy:  0.1300 - auc:  0.7397 - val_binary_crossentropy:  0.1293 - val_auc:  0.7218
# Epoch 27/50
# 9s - loss:  0.1299 - binary_crossentropy:  0.1299 - auc:  0.7422 - val_binary_crossentropy:  0.1290 - val_auc:  0.7241
# Epoch 28/50
# 9s - loss:  0.1296 - binary_crossentropy:  0.1296 - auc:  0.7439 - val_binary_crossentropy:  0.1294 - val_auc:  0.7225
# Epoch 29/50
# 9s - loss:  0.1294 - binary_crossentropy:  0.1294 - auc:  0.7459 - val_binary_crossentropy:  0.1293 - val_auc:  0.7229
# Epoch 30/50
# 9s - loss:  0.1292 - binary_crossentropy:  0.1292 - auc:  0.7482 - val_binary_crossentropy:  0.1299 - val_auc:  0.7237
# Epoch 31/50
# 9s - loss:  0.1291 - binary_crossentropy:  0.1291 - auc:  0.7476 - val_binary_crossentropy:  0.1293 - val_auc:  0.7244
# Epoch 32/50
# 9s - loss:  0.1288 - binary_crossentropy:  0.1289 - auc:  0.7505 - val_binary_crossentropy:  0.1290 - val_auc:  0.7282
# Epoch 33/50
# 9s - loss:  0.1287 - binary_crossentropy:  0.1287 - auc:  0.7500 - val_binary_crossentropy:  0.1286 - val_auc:  0.7285
# Epoch 34/50
# 9s - loss:  0.1285 - binary_crossentropy:  0.1285 - auc:  0.7515 - val_binary_crossentropy:  0.1286 - val_auc:  0.7286
# Epoch 35/50
# 9s - loss:  0.1283 - binary_crossentropy:  0.1283 - auc:  0.7536 - val_binary_crossentropy:  0.1286 - val_auc:  0.7303
# Epoch 36/50
# 10s - loss:  0.1281 - binary_crossentropy:  0.1281 - auc:  0.7550 - val_binary_crossentropy:  0.1285 - val_auc:  0.7299
# Epoch 37/50
# 10s - loss:  0.1279 - binary_crossentropy:  0.1279 - auc:  0.7568 - val_binary_crossentropy:  0.1286 - val_auc:  0.7293
# Epoch 38/50
# 9s - loss:  0.1278 - binary_crossentropy:  0.1278 - auc:  0.7570 - val_binary_crossentropy:  0.1285 - val_auc:  0.7293
# Epoch 39/50
# 10s - loss:  0.1277 - binary_crossentropy:  0.1277 - auc:  0.7567 - val_binary_crossentropy:  0.1284 - val_auc:  0.7319
# Epoch 40/50
# 9s - loss:  0.1275 - binary_crossentropy:  0.1275 - auc:  0.7595 - val_binary_crossentropy:  0.1290 - val_auc:  0.7303
# Epoch 41/50
# 9s - loss:  0.1273 - binary_crossentropy:  0.1273 - auc:  0.7600 - val_binary_crossentropy:  0.1285 - val_auc:  0.7303
# Epoch 42/50
# 9s - loss:  0.1272 - binary_crossentropy:  0.1272 - auc:  0.7608 - val_binary_crossentropy:  0.1290 - val_auc:  0.7283
# Epoch 43/50
# 10s - loss:  0.1272 - binary_crossentropy:  0.1272 - auc:  0.7603 - val_binary_crossentropy:  0.1287 - val_auc:  0.7293
# Epoch 44/50
# 9s - loss:  0.1269 - binary_crossentropy:  0.1269 - auc:  0.7640 - val_binary_crossentropy:  0.1288 - val_auc:  0.7327
# Epoch 00044: early stopping
#
# test LogLoss 0.1309
# test AUC 0.7353
# test RIG 0.0755
